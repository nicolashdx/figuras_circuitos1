# %%
import schemdraw
import schemdraw.elements as elm

from PIL import Image
import matplotlib.pyplot as plt

import os

# %%
def next_name(folder_path):
    # Listar todos os arquivos na pasta que terminam com .png
    png_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]
    
    if not png_files:
        # Se não houver arquivos JPG, o primeiro nome será "1.png"
        return "1.png"
    
    # Remover a extensão e converter para inteiro para ordenar
    numbers = [int(os.path.splitext(f)[0]) for f in png_files]
    
    # Encontrar o maior número e adicionar 1
    next_number = max(numbers) + 1
    
    # Retornar o próximo nome de arquivo
    return f"{next_number}.png"

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4)
    
    V1 = elm.SourceV().label("12 V")
    R1 = elm.Resistor().right().label("1 Ω")
    
    d.push()
    d.config(unit=2)
    R2 = elm.Resistor().down().label("4 Ω")
    C = elm.Capacitor().down().label("1 F")
    d.pop()

    d.config(unit=4)
    R1 = elm.Resistor().right().label("5 Ω")
    L = elm.Inductor().down().label("2 H")

    l = elm.Line().tox(V1.start)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2.5)
    R = elm.RBox().right().fill('gray').label(['+', 'v', '-'], loc='bottom', color='#3b8dbf', fontsize=24).label('A', loc='left').label('B', loc='right')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)
    D1 = elm.Ic(pins=[elm.IcPin(name='2', side='l', slot='1/2', anchorname='B', color='#3b8dbf'),
                      elm.IcPin(name='1', side='l', slot='2/2', anchorname='A', color='#3b8dbf'),
                      ], pinspacing=1.5).label('v', loc='left', ofst=(-1.15, 0), color='#3b8dbf', fontsize=16).fill('lightgrey')
    

    l1 = elm.Line(length=.5).left().at(D1.A).label('+', loc='left', color='#3b8dbf',fontsize=16)
    l2 = elm.Line().left().at(D1.B).label('-', loc='left', color='#3b8dbf',fontsize=28)

    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=True).at([l1.end[0]+0.4, l1.end[1]+.1]).label('i', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)
    D1 = elm.Ic(pins=[elm.IcPin(name='2', side='l', slot='1/2', anchorname='B'),
                      elm.IcPin(name='1', side='l', slot='2/2', anchorname='A'),
                      ], pinspacing=1.5).label('v', loc='left', ofst=(-1.15, 0), color='#3b8dbf', fontsize=16).fill('lightgrey')
    

    l1 = elm.Line(length=.5).left().at(D1.A).label('+', loc='left', color='#3b8dbf',fontsize=16)
    l2 = elm.Line().left().at(D1.B).label('-', loc='left', color='#3b8dbf',fontsize=28)

    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=True).at([l1.end[0]+0.4, l1.end[1]+.1]).label('i', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)
    D1 = elm.Ic(pins=[elm.IcPin(name='2', side='l', slot='1/2', anchorname='B'),
                      elm.IcPin(name='1', side='l', slot='2/2', anchorname='A'),
                      ], pinspacing=1.5).label('v', loc='left', ofst=(-1.15, 0), color='#3b8dbf', fontsize=16).fill('lightgrey')
    

    l1 = elm.Line(length=.5).left().at(D1.A).label('+', loc='left', color='#3b8dbf',fontsize=16)
    l2 = elm.Line().left().at(D1.B).label('-', loc='left', color='#3b8dbf',fontsize=28)

    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=False).at([l1.end[0]+0.4, l1.end[1]+.1]).label('i', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)
    D1 = elm.Ic(pins=[elm.IcPin(name='2', side='l', slot='1/2', anchorname='B'),
                      elm.IcPin(name='1', side='l', slot='2/2', anchorname='A'),
                      ], pinspacing=1.5).label('v', loc='left', ofst=(-1.15, 0), color='#3b8dbf', fontsize=16).fill('lightgrey')
    

    l1 = elm.Line(length=.5).left().at(D1.A).label('-', loc='left', color='#3b8dbf',fontsize=28)
    l2 = elm.Line().left().at(D1.B).label('+', loc='left', color='#3b8dbf',fontsize=16)

    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=True).at([l1.end[0]+0.4, l1.end[1]+.1]).label('i', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)
    D1 = elm.Ic(pins=[elm.IcPin(name='2', side='l', slot='1/2', anchorname='B'),
                      elm.IcPin(name='1', side='l', slot='2/2', anchorname='A'),
                      ], pinspacing=1.5).label('v', loc='left', ofst=(-1.15, 0), color='#3b8dbf', fontsize=16).fill('lightgrey')
    

    l1 = elm.Line(length=.5).left().at(D1.A).label('-', loc='left', color='#3b8dbf',fontsize=28)
    l2 = elm.Line().left().at(D1.B).label('+', loc='left', color='#3b8dbf',fontsize=16)

    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=False).at([l1.end[0]+0.4, l1.end[1]+.1]).label('i', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)

    d1 = elm.Dot().label('A', loc='top').label("+", loc='left', fontsize=16)
    l1 = elm.Line().right()
    l2 = elm.Line().down()

    R = elm.RBox().down().fill('lightblue').label("5V", loc="top", ofst=(0,-.8))

    l3 = elm.Line().down()
    l4 = elm.Line().left()

    d2 = elm.Dot().label('B', loc='bot').label("-", loc='left', fontsize=28)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)

    d1 = elm.Dot().label('A', loc='top').label("+", loc='left', fontsize=16)
    l1 = elm.Line().right()
    l2 = elm.Line().down()

    R = elm.RBox().down().fill('#00FF00').label("5V", loc="top", ofst=(0,-.8))

    l3 = elm.Line().down()
    l4 = elm.Line().left()

    d2 = elm.Dot().label('B', loc='bot').label("-", loc='left', fontsize=28)

    
    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=True).at([l1.center.x+0.1, l1.center.y]).label('2A', loc='top')


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)

    d1 = elm.Dot().label('A', loc='top').label("-", loc='left', fontsize=28)
    l1 = elm.Line().right()
    l2 = elm.Line().down()

    R = elm.RBox().down().fill('#FF0000').label("5V", loc="top", ofst=(0,-.8))

    l3 = elm.Line().down()
    l4 = elm.Line().left()

    d2 = elm.Dot().label('B', loc='bot').label("+", loc='left', fontsize=16)

    
    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=False).at([l1.center.x+0.1, l1.center.y]).label('2A', loc='top')


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)

    d1 = elm.Dot().label('A', loc='top').label("+", loc='left', fontsize=16)
    l1 = elm.Line().right()
    l2 = elm.Line().down()

    R = elm.RBox().down().fill('orange').label("5V", loc="top", ofst=(0,-.8))

    l3 = elm.Line().down()
    l4 = elm.Line().left()

    d2 = elm.Dot().label('B', loc='bot').label("-", loc='left', fontsize=28)

    
    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=False).at([l1.center.x+0.1, l1.center.y]).label('2A', loc='top')


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)

    d1 = elm.Dot().label('A', loc='top').label("-", loc='left', fontsize=28)
    l1 = elm.Line().right()
    l2 = elm.Line().down()

    R = elm.RBox().down().fill('blue').label("5V", loc="top", ofst=(0,-.8))

    l3 = elm.Line().down()
    l4 = elm.Line().left()

    d2 = elm.Dot().label('B', loc='bot').label("+", loc='left', fontsize=16)

    
    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=True).at([l1.center.x+0.1, l1.center.y]).label('2A', loc='top')


    #d.save(next_name("./"), dpi=600, transparent=True)
