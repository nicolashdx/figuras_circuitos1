# %%
import schemdraw
import schemdraw.elements as elm

from PIL import Image
import matplotlib.pyplot as plt

import os

# %%
def next_name(folder_path):
    # Listar todos os arquivos na pasta que terminam com .png
    png_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]
    
    if not png_files:
        # Se não houver arquivos JPG, o primeiro nome será "1.png"
        return "1.png"
    
    # Remover a extensão e converter para inteiro para ordenar
    numbers = [int(os.path.splitext(f)[0]) for f in png_files]
    
    # Encontrar o maior número e adicionar 1
    next_number = max(numbers) + 1
    
    # Retornar o próximo nome de arquivo
    return f"{next_number}.png"

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4, fontsize=18)
    
    v1 = elm.SourceV().label('V')

    l1 = elm.Line().right()
    d.config(unit=2)

    d1 = elm.Dot().label('a', loc='top')
    d.config(unit=3)

    r1 = elm.Resistor().right().label('R$_1$', loc='top').label(['+', 'V$_1$', '-'], loc='bot', color='blue')
    d1 = elm.Dot().label('b', loc='top')
    r2 = elm.Resistor().right().label('R$_2$', loc='top').label(['+', 'V$_2$', '-'], loc='bot', color='blue')

    l2 = elm.Line().down()
    d.config(unit=4)
    
    l3 = elm.Line().left().tox(v1.start)

    d3 = elm.Dot().label('c', loc='bot').at((r1.start[0], l3.center[1]))

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=True).at(l1.center).label('i', loc='top', fontsize=16).color('red')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4, fontsize=18)
    
    d1 = elm.Dot().label('h', loc='bot')
    v1 = elm.SourceV().label('V$_s$', loc='top')
    d2 = elm.Dot().label('a', loc='top')

    r1 = elm.Resistor().right().label('R$_1$')
    d3 = elm.Dot().label('b', loc='top')

    r2 = elm.Resistor().right().label('R$_2$')
    d4 = elm.Dot().label('c', loc='top')

    r3 = elm.Resistor().right().label('R$_3$')
    d5 = elm.Dot().label('d', loc='top')

    r4 = elm.Resistor().down().label('R$_4$', loc='bot')
    d6 = elm.Dot().label('e', loc='bot')

    r5 = elm.Resistor().left().label('R$_5$')
    d7 = elm.Dot().label('f', loc='bot')

    r5 = elm.Resistor().left().label('R$_6$')
    d8 = elm.Dot().label('g', loc='bot')

    r5 = elm.Resistor().left().label('R$_7$')

    A1 = elm.CurrentLabel(top=True, ofst=-1.25, length=1, reverse=False).at(v1).label('i$_s$', loc='bot', fontsize=16).color('gray')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=16)
    l1 = elm.Line().right()
    d1 = elm.Dot().label('a', loc='top')
    
    r1 = elm.Resistor().right().label('R$_1$')

    r2 = elm.Resistor().right().label('R$_2$')

    r3 = elm.Resistor().right().label('R$_3$')

    r4 = elm.Resistor().down().label('R$_4$', loc='bot').label(['+', 'V$_s$', '-'], loc='top', ofst=(0, -7.5), color='gray', fontsize=16)

    r5 = elm.Resistor().left().label('R$_5$', loc='bot')

    r5 = elm.Resistor().left().label('R$_6$', loc='bot')

    r5 = elm.Resistor().left().label('R$_7$', loc='bot')
    d2 = elm.Dot().label('h', loc='bot')

    l2 = elm.Line().left()

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=True).at((l1.start[0]+.75, l1.start[1])).label('i$_s$', loc='top', fontsize=16).color('gray')

    rect = elm.Rect(corner1=(r1.start[0]-11, r1.start[1]+1), corner2=(r5.start[0]-5.5, r5.start[1]-1), fill='lightgrey')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=16)
    lt = elm.Line().right()
    d1 = elm.Dot().label('a', loc='top')
    
    d.config(unit=.75)
    l1 = elm.Line().right()

    r1 = elm.Resistor().down().label('R$_e$$_q$', loc='bot').label(['+', 'V$_s$', '-'], loc='top', ofst=(0, -2.25), color='gray', fontsize=16)
    d.config(unit=2)

    l2 = elm.Line().left()
    d.config(unit=.75)

    d2 = elm.Dot().label('h', loc='bot')

    d.config(unit=2)
    lb = elm.Line().left()

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=True).at((lt.start[0]+.75, lt.start[1])).label('i$_s$', loc='top', fontsize=16).color('gray')

    rect = elm.Rect(corner1=(r1.start[0]-6.75, r1.start[1]+.75), corner2=(r1.end[0]-4.25, r1.end[1]-.75), fill='lightgrey')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4, fontsize=18)
    
    v1 = elm.SourceV().label('V', loc='top')
    l1 = elm.Line().right()

    d.push()
    r1 = elm.Resistor().down().label('R$_1$', loc='bot')
    d.pop()

    l2 = elm.Line().right()
    r2 = elm.Resistor().down().label('R$_2$', loc='bot')

    l3 = elm.Line().left().tox(v1.start)

    d1 = elm.Dot().at((l1.start[0]+2.5, l1.start[1])).label('a', loc='top')
    d2 = elm.Dot().at((l3.end[0]+2.5, l3.end[1])).label('b', loc='bot')

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=True).at((l1.start[0]+.75, l1.start[1])).label('i', loc='top', fontsize=16)
    A2 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=False).at((r1.start[0], r1.start[1]-.75)).label('i$_1$', loc='top', fontsize=16).theta(-90)
    A3 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=False).at((r2.start[0], r2.start[1]-.75)).label('i$_2$', loc='top', fontsize=16).theta(-90)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=16)
    l1 = elm.Line().right()
    d1 = elm.Dot().label('a', loc='top')
    
    d.config(unit=1)
    l3 = elm.Line().right()

    d.push()
    d.config(unit=2)
    r1 = elm.Resistor().down().label('R$_1$', loc='bot')
    d.pop()

    l4 = elm.Line().right()

    d.push()
    r2 = elm.Resistor().down().label('R$_2$', loc='bot')
    d.pop()

    l5 = elm.Line().right()
    d.push()
    r3 = elm.Resistor().down().label('R$_3$', loc='bot')
    d.pop()

    l6 = elm.Line().right()
    r4 = elm.Resistor().down().label('R$_4$', loc='bot')

    l2 = elm.Line().left().tox(l1.start)
    d2 = elm.Dot().label('b', loc='bot').at((l1.end[0], l2.start[1]))

    v1 = elm.SourceV().up().label('V$_s$', loc='top').at(l2.end)

    A1 = elm.CurrentLabel(top=True, ofst=.3, length=1, reverse=False).at((l1.start[0]+.75, l1.start[1])).label('i$_s$', loc='top', fontsize=16).color('gray').theta(0)

    rect = elm.Rect(corner1=(r1.start[0]-5.75, r1.start[1]-1.5), corner2=(r5.start[0]-3.25, r5.start[1]-8), fill='lightgrey')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=16)
    l1 = elm.Line().right()
    d1 = elm.Dot().label('a', loc='top')
    
    d.config(unit=1)
    l3 = elm.Line().right()

    d.config(unit=2)
    r1 = elm.Resistor().down().label('R$_e$$_q$', loc='bot')

    l2 = elm.Line().left().tox(l1.start)
    d2 = elm.Dot().label('h', loc='bot').at((l1.end[0], l2.start[1]))

    v1 = elm.SourceV().up().label('V$_s$', loc='top').at(l2.end)

    A1 = elm.CurrentLabel(top=True, ofst=.3, length=1, reverse=False).at((l1.start[0]+.75, l1.start[1])).label('i$_s$', loc='top', fontsize=16).color('gray').theta(0)

    rect = elm.Rect(corner1=(r1.start[0]-6.75, r1.start[1]-1.5), corner2=(r5.start[0]-3.25, r5.start[1]-3.25), fill='lightgrey')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4, fontsize=18)
    
    v1 = elm.SourceV().label('V', loc='top')
    l1 = elm.Line().right()

    d.push()
    r1 = elm.Resistor().down().label('R$_1$', loc='bot')
    d.pop()

    l2 = elm.Line().right()
    r2 = elm.Resistor().down().label('R$_2$', loc='bot')

    l3 = elm.Line().left()

    r3 = elm.Resistor().left().label('R$_3$', loc='top')

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=True).at((l1.start[0]+.75, l1.start[1])).label('i', loc='top', fontsize=16)
    A2 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=False).at((r1.start[0], r1.start[1]-.75)).label('i$_1$', loc='top', fontsize=16).theta(-90)
    A3 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=False).at((r2.start[0], r2.start[1]-.75)).label('i$_2$', loc='top', fontsize=16).theta(-90)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    i1 = elm.SourceI().up().label('5 A', loc='top').label(['-', 'V', '+'], loc='bot', ofst=(0, -.85), color='blue')

    l1 = elm.Line().right()

    d1 = elm.Dot().label('a', loc='top')

    d.push()
    r1 = elm.Resistor().down().label('30 Ω', loc='bot')
    d.pop()

    r2 = elm.Resistor().right().label('7,2 Ω', loc='top')
    d2 = elm.Dot().label('b', loc='top')

    d.push()
    r3 = elm.Resistor().down().label('64 Ω', loc='bot')
    d.pop()

    r4 = elm.Resistor().right().label('6 Ω', loc='top')

    r5 = elm.Resistor().down().label('10 Ω', loc='bot')

    l2 = elm.Line().left().tox(i1.start)

    d3 = elm.Dot().label('c', loc='bot').at(l2.center)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1, fontsize=16)
    D1 = elm.Ic(pins=[elm.IcPin(name='', side='r', slot='1/2', anchorname='B', color='#3b8dbf'),
                      elm.IcPin(name='', side='r', slot='2/2', anchorname='A', color='#3b8dbf'),
                      ], pinspacing=3.5).label("Circuito", loc='center', ofst=(-.01,0)).label(['-', 'V$_t$', '+'], loc='right', ofst=(-.2, 0), color='blue', fontsize=16).fill('lightgrey')

    l1 = elm.Line().right().at(D1.A)
    d.config(unit=.5)
    l2 = elm.Line().right().at(D1.B)

    r1 = elm.Resistor().right().at(l1.end).label('R$_1$')
    d.config(unit=2)

    r2 = elm.Resistor().right().label('R$_2$')

    l3 = elm.Line().right().linestyle(':').length(1)

    l4 = elm.Line().right().length(1.25)

    r4 = elm.Resistor().down().length(3.5).label('R$_j$', loc='top').label(['+', 'V$_j$', '-'], loc='bot', color='blue')

    l5 = elm.Line().left().length(1.25)

    l6 = elm.Line().left().linestyle(':').length(1)

    r5 = elm.Resistor().left().label('R$_n$$_-$$_1$', loc='top')

    r6 = elm.Resistor().left().label('R$_n$', loc='top')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=16)
    
    v1 = elm.SourceV().up().label('V$_s$').length(6)

    l1 = elm.Line().right()
    d1 = elm.Dot()

    r1 = elm.Resistor().down().label('R$_1$')
    d2 = elm.Dot()

    d.push()
    r2 = elm.Resistor().down().label('R$_2$')
    d3 = elm.Dot()
    d.pop()

    l2 = elm.Line().right(6)

    r3 = elm.Resistor().down().label('R$_L$', loc='bot').label(['+', 'V$_o$', '-'], loc='top', ofst=(0, -2.5), color='blue')

    l3 = elm.Line().left().tox(v1.start)

    dp = elm.Dot().at(l2.center)
    dm = elm.Dot().at((l3.start[0]-3, l3.start[1]))

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=16)
    D1 = elm.Ic(pins=[elm.IcPin(name='', side='r', slot='1/2', anchorname='B', color='#3b8dbf'),
                      elm.IcPin(name='', side='r', slot='2/2', anchorname='A', color='#3b8dbf'),
                      ], pinspacing=3.5).label("Circuito", loc='center', ofst=(-.01,0)).fill('lightgrey')

    l1 = elm.Line().right().at(D1.A)
    l2 = elm.Line().right().at(D1.B)

    d1 = elm.Dot().at(l1.end)
    d.config(unit=3.5)
    d.push()
    r1 = elm.Resistor().down().label('R$_1$')
    d2 = elm.Dot()
    d.pop()

    l3 = elm.Line().right().length(2)

    d3 = elm.Dot()
    d.push()
    r2 = elm.Resistor().down().label('R$_2$')
    d4 = elm.Dot()
    l4 = elm.Line().left()
    d.pop()

    l5 = elm.Line().right().length(1)
    l6 = elm.Line().right().length(1).linestyle(':')
    l7 = elm.Line().right().length(1)

    d5 = elm.Dot()
    d.push()
    r3 = elm.Resistor().down().label('R$_j$')
    d6 = elm.Dot()
    l8 = elm.Line().left().length(1)
    l9 = elm.Line().left().length(1).linestyle(':')
    l10 = elm.Line().left().length(1)
    d.pop()

    l11 = elm.Line().right().length(1)
    l12 = elm.Line().right().length(1).linestyle(':')
    l13 = elm.Line().right().length(1)
    
    d7 = elm.Dot()
    d.push()
    r4 = elm.Resistor().down().label('R$_n$$_-$$_1$')
    d8 = elm.Dot()
    l14 = elm.Line().left().length(1)
    l15 = elm.Line().left().length(1).linestyle(':')
    l16 = elm.Line().left().length(1)
    d.pop()

    l17 = elm.Line().right().length(2)

    r5 = elm.Resistor().down().label('R$_n$').label(['+', 'V', '-'], loc='bot', color='blue')

    l18 = elm.Line().left().length(2)

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=True).at((l1.start[0]+.75, l1.start[1])).label('i', loc='top', fontsize=16).color('blue')
    A2 = elm.CurrentLabel(top=True, ofst=.3, length=1, reverse=False).at(r3).label('i$_j$', loc='bot', fontsize=16).color('blue')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=16)
    
    i1 = elm.SourceI().up().label('8 A').length(6)

    l1 = elm.Line().right()
    d1 = elm.Dot()

    d.push()
    r1 = elm.Resistor().down().length(3).label('36 Ω')
    r2 = elm.Resistor().down().length(3).label('44 Ω')
    d2 = elm.Dot()
    d.pop()

    l2 = elm.Line().right()
    d3 = elm.Dot()

    d.push()
    r3 = elm.Resistor().down().length(6).label('10 Ω')
    d4 = elm.Dot()
    d.pop()

    l3 = elm.Line().right()
    d5 = elm.Dot()

    d.push()
    r4 = elm.Resistor().down().length(2).label('40 Ω')
    r5 = elm.Resistor().down().length(2).label('10 Ω')
    r6 = elm.Resistor().down().length(2).label('30 Ω').label(['+', 'V$_o$', '-'], loc='bot', color='blue')
    d6 = elm.Dot()
    d.pop()

    l4 = elm.Line().right()

    r7 = elm.Resistor().down().length(6).label('24 Ω').label(['+', 'V', '-'], loc='bot')

    l5 = elm.Line().left().tox(i1.start)

    A1 = elm.CurrentLabel(top=True, ofst=.3, length=1, reverse=False).at((r7.start[0], r7.start[1]-.6)).label('i$_o$', loc='bot', fontsize=16).color('blue').theta(-90)


    #d.save(next_name("./"), dpi=600, transparent=True)
