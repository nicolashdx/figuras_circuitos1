# %%
import schemdraw
import schemdraw.elements as elm

from PIL import Image
import matplotlib.pyplot as plt

import os

# %%
def next_name(folder_path):
    # Listar todos os arquivos na pasta que terminam com .png
    png_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]
    
    if not png_files:
        # Se não houver arquivos JPG, o primeiro nome será "1.png"
        return "1.png"
    
    # Remover a extensão e converter para inteiro para ordenar
    numbers = [int(os.path.splitext(f)[0]) for f in png_files]
    
    # Encontrar o maior número e adicionar 1
    next_number = max(numbers) + 1
    
    # Retornar o próximo nome de arquivo
    return f"{next_number}.png"

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    op = elm.Opamp(sign=True)

    li1 = elm.Line().left(1).at((op.in1[0], op.in1[1])).dot()
    li2 = elm.Line().left(1).at((op.in2[0], op.in2[1])).dot()
    lout = elm.Line().right(1).at((op.out[0], op.out[1])).dot()
    lvcc = elm.Line().up(1).at((op.vd[0], op.vd[1])).dot()
    lgnd = elm.Line().down(1).at((op.vs[0], op.vs[1])).dot()
    
    # INVERTER ENTRADAS INVERSORA E NÃO INVERSORA
    newpath = [list(p[:]) for p in op.segments[3].path] # criando cópia dos pontos do sinal de +
    for p in newpath:
        p[1] = p[1]*(-1) # modificando os pontos
    op.segments[3].path = newpath # atualizando posição do sinal

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    op = elm.Opamp(sign=True)

    li1 = elm.Line().left(1).at((op.in1[0], op.in1[1])).dot()
    li2 = elm.Line().left(1).at((op.in2[0], op.in2[1])).dot()
    lout = elm.Line().right(1).at((op.out[0], op.out[1])).dot()
    lvcc = elm.Line().up(1).at((op.vd[0], op.vd[1])).label('V$^+$', loc='right').dot()
    lvdd = elm.Line().down(1).at((op.vs[0], op.vs[1])).label('V$^-$', loc='left').dot()
    
    # INVERTER ENTRADAS INVERSORA E NÃO INVERSORA
    newpath = [list(p[:]) for p in op.segments[3].path] # criando cópia dos pontos do sinal de +
    for p in newpath:
        p[1] = p[1]*(-1) # modificando os pontos
    op.segments[3].path = newpath # atualizando posição do sinal

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    op = elm.Opamp(sign=True)

    li1 = elm.Line().left(1).at((op.in1[0], op.in1[1])).dot()
    li2 = elm.Line().left(1).at((op.in2[0], op.in2[1])).dot()
    lout = elm.Line().right(1).at((op.out[0], op.out[1])).dot()
    lvcc = elm.Line().up(1).at((op.vd[0], op.vd[1])).label('V$^+$', loc='right').dot()
    lvdd = elm.Line().down(1).at((op.vs[0], op.vs[1])).label('V$^-$', loc='bot').dot()
    
    # INVERTER ENTRADAS INVERSORA E NÃO INVERSORA
    newpath = [list(p[:]) for p in op.segments[3].path] # criando cópia dos pontos do sinal de +
    for p in newpath:
        p[1] = p[1]*(-1) # modificando os pontos
    op.segments[3].path = newpath # atualizando posição do sinal

    vccmenos = elm.Battery().down(2).label(['-','V$_C$$_C$','+'], loc='top').reverse().dot()
    elm.GroundSignal(fill=True)

    l1 = elm.Line().left(3).at(li1.end)
    l2 = elm.Line().left(1.5).at(li2.end)

    l3 = elm.Line().left().at(vccmenos.end).tox(l1.end)
    l4 = elm.Line().right(5).at(vccmenos.end)

    vccmais = elm.Battery().up().reverse().toy(lvcc.end).label(['-','V$_C$$_C$','+'], loc='bot')
    l5 = elm.Line().left().tox(lvcc.end)

    elm.Gap().at(l1.end).toy(l3.end).label(['+','$V_p$','-']).color('#3b8dbf')
    elm.Gap().at(l2.end).toy(l3.end).label(['+','$V_n$','-']).color('#3b8dbf')
    elm.Gap().at(lout.end).toy(l3.end).label(['+','$V_o$','-']).color('#3b8dbf')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    op = elm.Opamp(sign=True)

    li1 = elm.Line().left(1).at((op.in1[0], op.in1[1]))
    li2 = elm.Line().left(1).at((op.in2[0], op.in2[1]))
    lout = elm.Line().right(1).at((op.out[0], op.out[1]))
    lvcc = elm.Line().up(1).at((op.vd[0], op.vd[1])).label('V$^+$', loc='right')
    lvdd = elm.Line().down(1).at((op.vs[0], op.vs[1])).label('V$^-$', loc='bot')
    
    # INVERTER ENTRADAS INVERSORA E NÃO INVERSORA
    newpath = [list(p[:]) for p in op.segments[3].path] # criando cópia dos pontos do sinal de +
    for p in newpath:
        p[1] = p[1]*(-1) # modificando os pontos
    op.segments[3].path = newpath # atualizando posição do sinal

    vccmenos = elm.Battery().down(2).label(['-','V$_C$$_C$','+'], loc='top').reverse().dot()
    elm.GroundSignal(fill=True)

    l1 = elm.Line().left(3).at(li1.end)
    l2 = elm.Line().left(3).at(li2.end)

    l3 = elm.Line().left().at(vccmenos.end).tox(l1.end)
    l4 = elm.Line().right(5).at(vccmenos.end)

    vccmais = elm.Battery().up().reverse().toy(lvcc.end).label(['-','V$_C$$_C$','+'], loc='bot')
    l5 = elm.Line().left().tox(lvcc.end)

    l6 = elm.Line().right(2).at(lout.end)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=False, ofst=0).at(l1.end+.5).label('i$_p$', loc='top').color('#3b8dbf')
    A2 = elm.CurrentLabel(top=True, length=1, reverse=False, ofst=-1).at(l2.end+.5).label('i$_n$', loc='bot').color('#3b8dbf')
    A3 = elm.CurrentLabel(top=True, length=1, reverse=True, ofst=-1).at(lout.end+.5).label('i$_o$', loc='bot').color('#3b8dbf')
    A4 = elm.CurrentLabel(top=True, length=1, reverse=False, ofst=-.5).at(l5).label('i$_c$$_+$', loc='top').color('#3b8dbf')
    A5 = elm.CurrentLabel(top=True, length=1, reverse=False, ofst=+.5).at(vccmenos).label('i$_c$$_-$', loc='bot').color('#3b8dbf')
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    op = elm.Opamp(sign=True)

    li1 = elm.Line().left(1).at((op.in1[0], op.in1[1])).dot()
    li2 = elm.Line().left(1).at((op.in2[0], op.in2[1])).dot()
    lout = elm.Line().right(1).at((op.out[0], op.out[1])).dot()
    lvcc = elm.Line().up(1).at((op.vd[0], op.vd[1])).label('V$^+$', loc='right').dot().color((0,0,0,0))
    lvdd = elm.Line().down(1).at((op.vs[0], op.vs[1])).label('V$^-$', loc='bot').dot().color((0,0,0,0))
    
    # INVERTER ENTRADAS INVERSORA E NÃO INVERSORA
    newpath = [list(p[:]) for p in op.segments[3].path] # criando cópia dos pontos do sinal de +
    for p in newpath:
        p[1] = p[1]*(-1) # modificando os pontos
    op.segments[3].path = newpath # atualizando posição do sinal

    vccmenos = elm.Battery().down(2).label(['-','V$_C$$_C$','+'], loc='top').reverse().dot().color((0,0,0,0))
    elm.GroundSignal(fill=True)

    l1 = elm.Line().left(3).at(li1.end)
    l2 = elm.Line().left(1.5).at(li2.end)

    l3 = elm.Line().left().at(vccmenos.end).tox(l1.end)
    l4 = elm.Line().right().at(vccmenos.end).tox(lout.end)

    vccmais = elm.Battery().up().reverse().toy(lvcc.end).label(['-','V$_C$$_C$','+'], loc='bot').color((0,0,0,0))
    l5 = elm.Line().left().tox(lvcc.end).color((0,0,0,0))

    elm.Gap().at(l1.end).toy(l3.end).label(['+','$V_p$','-']).color('#3b8dbf')
    elm.Gap().at(l2.end).toy(l3.end).label(['+','$V_n$','-']).color('#3b8dbf')
    elm.Gap().at(lout.end).toy(l3.end).label(['+','$V_o$','-']).color('#3b8dbf')

    A1 = elm.CurrentLabel(top=False, length=1, reverse=False, ofst=0).at(l1.end+.5).label('i$_p$', loc='top').theta(0).color('#3b8dbf')
    A2 = elm.CurrentLabel(top=True, length=1, reverse=False, ofst=0).at(l2.end+.5).label('i$_n$', loc='top').theta(0).color('#3b8dbf')
    A3 = elm.CurrentLabel(top=True, length=1, reverse=True, ofst=+1).at(lout.end-.5).label('i$_o$', loc='top').theta(0).color('#3b8dbf')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    op = elm.Opamp(sign=True)

    li1 = elm.Line().left(1).at((op.in1[0], op.in1[1])).dot().label('V$_p$', loc='left')
    li2 = elm.Line().left(1).at((op.in2[0], op.in2[1])).dot().label('V$_n$', loc='left')
    lout = elm.Line().right(1).at((op.out[0], op.out[1])).dot().label('V$_o$', loc='right', color='#3b8dbf')
    
    # INVERTER ENTRADAS INVERSORA E NÃO INVERSORA
    newpath = [list(p[:]) for p in op.segments[3].path] # criando cópia dos pontos do sinal de +
    for p in newpath:
        p[1] = p[1]*(-1) # modificando os pontos
    op.segments[3].path = newpath # atualizando posição do sinal

    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)

    elm.Dot().label('V$_p$', loc='left')
    l1 = elm.Line().right()
    d.push()
    elm.Gap().down().label(['+','V$_i$$_n$','-']).color('#3b8dbf')
    l2 = elm.Line().left()
    elm.Dot().label('V$_n$', loc='left')
    d.pop()

    elm.Line().right(2).color((0,0,0,0))
    d.push()
    l3 = elm.Line().right().dot()
    d.pop()
    vout = elm.SourceControlledV().down().reverse().label('AV$_i$$_n$', loc='bot', color='red')

    l4 = elm.Line().right().dot()
    elm.GroundSignal(fill=True)

    elm.Gap().down().at(l3.end).toy(l4.end).label(['+','V$_o$','-']).color('#3b8dbf')

    rect1 = elm.Rect(corner1=((l1.center[0]-.5, l1.center[1]+.5)), corner2=((l4.center[0]+.5, l4.center[1]-.5)), fill='#ddd', lw=2, ls='--').theta(180)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)

    elm.Dot().label('V$_p$', loc='left')
    l1 = elm.Line().right()
    d.push()
    elm.Resistor().down().label('R$_i$$_n$', loc='bot', ofst=(.8, 0)).label(['+','V$_i$$_n$','-'], color='#3b8dbf')
    l2 = elm.Line().left()
    elm.Dot().label('V$_n$', loc='left')
    d.pop()

    elm.Line().right(2).color((0,0,0,0))
    d.push()
    elm.Resistor().right(2).label('R$_o$$_u$$_t$', loc='bot')
    l3 = elm.Line().right(1).dot()
    d.pop()
    vout = elm.SourceControlledV().down().reverse().label('AV$_i$$_n$', loc='bot', color='red')

    l4 = elm.Line().right().dot()
    elm.GroundSignal(fill=True)

    elm.Gap().down().at(l3.end).toy(l4.end).label(['+','V$_o$','-']).color('#3b8dbf')

    rect1 = elm.Rect(corner1=((l1.center[0]-.5, l1.center[1]+.5)), corner2=((l4.center[0]+.5, l4.center[1]-.5)), fill='#ddd', lw=2, ls='--').theta(180)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    op = elm.Opamp(sign=True)

    li1 = elm.Line().left(1).at((op.in1[0], op.in1[1])).dot()
    li2 = elm.Line().left(1).at((op.in2[0], op.in2[1]))
    lout = elm.Line().right(3).at((op.out[0], op.out[1])).dot()
    
    lvcc = elm.Line().up(1).at((op.vd[0], op.vd[1])).dot().label('10V', loc='bot')
    lvdd = elm.Line().down(1).at((op.vs[0], op.vs[1])).dot().label('-10V', loc='bot')
    
    # INVERTER ENTRADAS INVERSORA E NÃO INVERSORA
    newpath = [list(p[:]) for p in op.segments[3].path] # criando cópia dos pontos do sinal de +
    for p in newpath:
        p[1] = p[1]*(-1) # modificando os pontos
    op.segments[3].path = newpath # atualizando posição do sinal
    
    ra = elm.Resistor().left().at(li1.end).label('R$_a$')
    va = elm.SourceV().down(4).reverse().label('V$_a$')
    elm.GroundSignal(fill=True)
    elm.Line().up(2).at(li1.end)
    rf = elm.Resistor().right().tox(lout.center).label('R$_f$')
    elm.Line().toy(lout.end).dot()

    vb = elm.SourceV().down().reverse().at(li2.end).toy(va.end).label('V$_b$')
    elm.GroundSignal(fill=True)

    elm.Gap().at(lout.end).toy(va.end).label(['+','V$_o$','-']).color('#3b8dbf')
    g = elm.GroundSignal(fill=True)

    g.segments[0].path[0] = (0, -.5)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    op = elm.Opamp(sign=True)

    li1 = elm.Line().left(1).at((op.in1[0], op.in1[1])).dot()
    li2 = elm.Line().left(1).at((op.in2[0], op.in2[1]))
    lout = elm.Line().right(3).at((op.out[0], op.out[1])).dot()
    
    lvcc = elm.Line().up(1).at((op.vd[0], op.vd[1])).dot().label('10V', loc='bot')
    lvdd = elm.Line().down(1).at((op.vs[0], op.vs[1])).dot().label('-10V', loc='bot')
    
    # INVERTER ENTRADAS INVERSORA E NÃO INVERSORA
    newpath = [list(p[:]) for p in op.segments[3].path] # criando cópia dos pontos do sinal de +
    for p in newpath:
        p[1] = p[1]*(-1) # modificando os pontos
    op.segments[3].path = newpath # atualizando posição do sinal
    
    ra = elm.Resistor().left().at(li1.end).label('25kΩ')
    va = elm.SourceV().down(4).reverse().label('V$_a$')
    elm.GroundSignal(fill=True)
    elm.Line().up(2).at(li1.end)
    rf = elm.Resistor().right().tox(lout.center).label('100kΩ')
    elm.Line().toy(lout.end).dot()

    vb = elm.SourceV().down().reverse().at(li2.end).toy(va.end).label('V$_b$')
    elm.GroundSignal(fill=True)

    elm.Gap().at(lout.end).toy(va.end).label(['+','V$_o$','-']).color('#3b8dbf')
    g = elm.GroundSignal(fill=True)

    g.segments[0].path[0] = (0, -.5)

    A1 = elm.CurrentLabel(top=True, length=1, reverse=True, ofst=-.1).at(rf.start+.5).label('i$_{100}$', loc='top').theta(0).color('#3b8dbf')
    A2 = elm.CurrentLabel(top=False, length=1, reverse=False, ofst=-.5).at(ra.center).label('i$_{25}$', loc='bot').theta(0).color('#3b8dbf')

    
    #d.save(next_name("./"), dpi=600, transparent=True)
