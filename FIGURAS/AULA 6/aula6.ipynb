# %%
import schemdraw
import schemdraw.elements as elm

from PIL import Image
import matplotlib.pyplot as plt

import os

# %%
def next_name(folder_path):
    # Listar todos os arquivos na pasta que terminam com .png
    png_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]
    
    if not png_files:
        # Se não houver arquivos JPG, o primeiro nome será "1.png"
        return "1.png"
    
    # Remover a extensão e converter para inteiro para ordenar
    numbers = [int(os.path.splitext(f)[0]) for f in png_files]
    
    # Encontrar o maior número e adicionar 1
    next_number = max(numbers) + 1
    
    # Retornar o próximo nome de arquivo
    return f"{next_number}.png"

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    V2 = elm.SourceV().label('V$_2$')
    d6 = elm.Dot().label('c', loc='left')
    V1 = elm.SourceV().label('V$_1$')
    
    d1 = elm.Dot().label('a', loc='left')
    r1 = elm.Resistor().right().label('R$_1$').length(6)
    
    d2 = elm.Dot().label('b', loc='top')
    
    d.push()
    r5 = elm.Resistor().down().label('R$_5$', loc='bot')
    d3 = elm.Dot().label('e', loc='right')
    
    d.push()
    r3 = elm.Resistor().left().label('R$_3$')
    d4 = elm.Dot().label('d', loc='top')
    r2 = elm.Resistor().left().label('R$_2$')
    d.pop()

    r6 = elm.Resistor().down().label('R$_6$', loc='bot')
    d5 = elm.Dot().label('g', loc='bot')

    r4 = elm.Resistor().left().label('R$_4$', loc='top').length(6)
    d5 = elm.Dot().label('f', loc='bot')
    d.pop()

    l1 = elm.Line().right().length(2)
    d.push()
    elm.Dot()
    r7 = elm.Resistor().down().label('R$_7$', loc='bot').length(6)
    elm.Dot()
    d.pop()

    l2 = elm.Line().right().length(2)
    i1 = elm.SourceI().down().length(6).reverse().label('I$_3$', loc='bot')
    
    l3 = elm.Line().left().tox(r6.end)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3.5, fontsize=18)
    
    V2 = elm.SourceV().label('V$_s$')
    r1 = elm.Resistor().right().label('R$_1$').length(5)
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('R$_6$')
    d2 = elm.Dot()
    r5 = elm.Resistor().left().label('R$_5$').length(5)
    d.pop()

    r2 = elm.Resistor().right().label('R$_2$').length(5)
    d3 = elm.Dot()
    r3 = elm.Resistor().down().label('R$_3$', loc='bot')
    d3 = elm.Dot()
    r4 = elm.Resistor().left().label('R$_4$').length(5)

    r7 = elm.Resistor().endpoints(r6.start, [r4.center[0], r3.center[1]]).label('R$_7$')
    l1 = elm.Line().endpoints(r7.end, r3.end)

    r8 = elm.Resistor().endpoints(r3.start, [r4.center[0], r3.center[1]]).label('R$_8$', loc='bot')
    l1 = elm.Line().endpoints(r8.end, r4.end)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3.5, fontsize=18)
    
    V2 = elm.SourceV().label('V$_s$')
    r1 = elm.Resistor().right().label('R$_1$').length(5)
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('R$_6$')
    d2 = elm.Dot()
    r5 = elm.Resistor().left().label('R$_5$').length(5)
    d.pop()

    r2 = elm.Resistor().right().label('R$_2$').length(5)
    d3 = elm.Dot()
    r3 = elm.Resistor().down().label('R$_3$', loc='top')
    d3 = elm.Dot()
    r4 = elm.Resistor().left().label('R$_4$').length(5)

    l1 = elm.Line().endpoints(r3.start, [r4.center[0], r3.center[1]])

    r8 = elm.Resistor().label('R$_8$', loc='top').endpoints(l1.end, r4.end)
    
    l2 = elm.Line().at(r6.start).up().length(1.5)
    l3 = elm.Line().right().length(6.5)

    r7 = elm.Resistor().down().label('R$_7$').length(5)
    l4 = elm.Line().left().tox(r3.end)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3.5, fontsize=18)
    
    v1 = elm.SourceV().label('V$_s$')
    r1 = elm.Resistor().right().label('R$_1$')
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('R$_6$')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('R$_2$')
    d.push()
    r11 = elm.Resistor().down().label('R$_1$$_1$')
    elm.Dot()
    r5 = elm.Resistor().left().label('R$_5$', loc='bot')
    elm.Line().tox(v1.start)
    d.pop()

    d3 = elm.Dot()
    r3 = elm.Resistor().right().label('R$_3$', loc='top')
    l1 = elm.Line().down().length(3.5/2)
    elm.Dot()
    l2 = elm.Line().down().length(3.5/2)
    r4 = elm.Resistor().left().label('R$_4$', loc='bot')

    r7 = elm.Resistor().endpoints(r6.start, [r5.center[0], r11.center[1]]).label('R$_7$', ofst=(.25,0))
    l3 = elm.Line().endpoints(r7.end, r11.end)

    l4 = elm.Line().endpoints(r11.start, [r5.center[0], r11.center[1]])
    r9 = elm.Resistor().label('R$_9$', loc='top', ofst=(-.25,0)).endpoints(l4.end, r6.end)

    l5 = elm.Line().endpoints(r2.start, (7,2.625))
    r8 = elm.Resistor().endpoints(l5.end, l2.start).label('R$_8$', loc='top')

    l6 = elm.Line().endpoints(r6.end, (7,0.875))
    r10 = elm.Resistor().endpoints(l6.end, l2.start).label('R$_1$$_0$', loc='bot')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('10 V')
    r1 = elm.Resistor().right().label('1 Ω')
    d1 = elm.Dot().label('1', color='red')

    d.push()
    r6 = elm.Resistor().down().label('5 Ω')
    d2 = elm.Dot().label('3', color='red', loc='bot')
    d.pop()

    r2 = elm.Resistor().right().label('2 Ω')
    d.push()
    r11 = elm.Resistor().down().label('10 Ω')
    elm.Dot()
    d.pop()

    d3 = elm.Dot().label('2', color='red')
    l1 = elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('2 A', loc='bot')
    l2 = elm.Line().left().tox(v1.start)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('10 V')
    r1 = elm.Resistor().right().label('1 Ω')
    d1 = elm.Dot().label('1')

    d.push()
    r6 = elm.Resistor().down().label('5 Ω').label(['+', 'V$_1$', '-'], loc='bot', color='#3b8dbf')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('2 Ω')
    d.push()
    r11 = elm.Resistor().down().label('10 Ω', loc='bot').label(['+', 'V$_2$', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()

    d3 = elm.Dot().label('2')
    l1 = elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('2 A', loc='bot')
    l2 = elm.Line().left().tox(v1.start)

    elm.GroundSignal().at(r6.end).fill('black')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    elm.Dot()
    l1 = elm.Line().left()

    v1 = elm.SourceV().label('10 V').label(['-', 'V$_1$', '+'], loc='bot', ofst=(0, -2.75), color='#3b8dbf')

    r1 = elm.Resistor().right().label('1 Ω').label(['-', 'iR', '+'], loc='bot', color='#3b8dbf')
    elm.Dot()

    elm.GroundSignal().at(l1.start).fill('black')

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=True).at((r1.end[0]-.5, r1.end[1]+1)).label('i', loc='top', color='#3b8dbf').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('50 V')
    r1 = elm.Resistor().right().label('1 Ω')
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('5 Ω', loc='bot')
    d2 = elm.Dot()
    d.pop()

    l3 = elm.Line().right()
    d.push()
    r11 = elm.Resistor().down().label('10 Ω', loc='bot')
    elm.Dot()
    d.pop()

    d3 = elm.Dot()
    l1 = elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('3 A', loc='bot')
    l2 = elm.Line().left().tox(v1.start)

    
    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r1).label('i$_a$', loc='bot', color='#3b8dbf').color('#3b8dbf')
    A2 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r6).label('i$_b$', loc='top', color='#3b8dbf').color('#3b8dbf')
    A3 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r11).label('i$_c$', loc='top', color='#3b8dbf').color('#3b8dbf')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('20 V')
    r1 = elm.Resistor().right().label('2 Ω')
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('20 Ω', loc='bot')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('5 Ω')
    d.push()
    r11 = elm.Resistor().down().label('10 Ω', loc='bot')
    elm.Dot()
    d.pop()

    d3 = elm.Dot()
    r3 = elm.Resistor().right().label('2 Ω')
    i2 = elm.SourceControlledV().down().reverse().label('8 i$_ϕ$', loc='bot')
    l2 = elm.Line().left().tox(v1.start)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r2).label('i$_ϕ$', loc='bot', color='#3b8dbf').color('#3b8dbf')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('100 V')
    elm.Line().right()
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('25 Ω', loc='bot').label(['+', 'V$_1$', '-'], loc='top', color='#3b8dbf')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('10 Ω')
    d.push()
    r11 = elm.Resistor().down().label('50 Ω', loc='bot').label(['+', 'V$_2$', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()

    d3 = elm.Dot()
    elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('5 A', loc='bot')
    l2 = elm.Line().left().tox(v1.start)

    elm.GroundSignal().at(r6.end).fill('black')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('50 V', loc='bot')
    elm.Line().right()
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('40 Ω', loc='bot')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('5 Ω')
    d.push()
    r11 = elm.Resistor().down().label('50 Ω', loc='bot')
    elm.Dot()
    d.pop()

    d3 = elm.Dot()
    v2 = elm.SourceControlledV().right().label('10 i$_ϕ$', loc='top')
    d.push()
    elm.Dot()
    r3 = elm.Resistor().down().label('100 Ω', loc='bot')
    elm.Dot()
    d.pop()
    elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('4 A', loc='bot')
    l2 = elm.Line().left().tox(v1.start)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=True).at(r2).label('i$_ϕ$', loc='bot', color='#3b8dbf').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('50 V', loc='bot')
    elm.Line().right()
    d1 = elm.Dot().label('1', loc='top')

    d.push()
    r6 = elm.Resistor().down().label('40 Ω', loc='bot').label(['+', 'V$_1$', '-'], loc='top', color='#3b8dbf')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('5 Ω')
    d.push()
    r11 = elm.Resistor().down().label('50 Ω', loc='bot').label(['+', 'V$_2$', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()

    d3 = elm.Dot().label('2', loc='top')
    v2 = elm.SourceControlledV().right().label('10 i$_ϕ$', loc='top')
    d.push()
    elm.Dot().label('3', loc='top')
    r3 = elm.Resistor().down().label('100 Ω', loc='bot').label(['+', 'V$_3$', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()
    elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('4 A', loc='bot')
    l2 = elm.Line().left().tox(v1.start)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=True).at(r2).label('i$_ϕ$', loc='bot', color='#3b8dbf').color('#3b8dbf')
    A2 = elm.CurrentLabel(top=False, length=1, reverse=False).at(v2).label('i', loc='bot', color='#3b8dbf').color('#3b8dbf')
    elm.GroundSignal().at(r6.end).fill('black')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('50 V', loc='bot')
    elm.Line().right()
    d1 = elm.Dot().label('1', loc='top')

    d.push()
    r6 = elm.Resistor().down().label('40 Ω', loc='bot').label(['+', 'V$_1$', '-'], loc='top', color='#3b8dbf')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('5 Ω')
    d.push()
    r11 = elm.Resistor().down().label('50 Ω', loc='bot').label(['+', 'V$_2$', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()

    d3 = elm.Dot().label('2', loc='top')
    elm.Line().right().color((0, 0, 0, 0))
    d.push()
    elm.Dot().label('3', loc='top')
    r3 = elm.Resistor().down().label('100 Ω', loc='bot').label(['+', 'V$_3$', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()
    elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('4 A', loc='bot')
    l2 = elm.Line().left().tox(v1.start)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=True).at(r2).label('i$_ϕ$', loc='bot', color='#3b8dbf').color('#3b8dbf')
    elm.GroundSignal().at(r6.end).fill('black')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceI().label('4,8 A', loc='top')
    elm.Line().right()
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('7,5 Ω', loc='bot')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('2,5 Ω')
    d.push()
    r11 = elm.Resistor().down().label('10 Ω', loc='bot').label(['+', 'V', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()

    d3 = elm.Dot()
    v2 = elm.SourceControlledV().right().label('i$_x$', loc='top')
    d.push()
    elm.Dot()
    r3 = elm.Resistor().down().label('2,5 Ω', loc='bot')
    elm.Dot()
    d.pop()
    r4 = elm.Resistor().right().label('1 Ω', loc='top')
    i2 = elm.SourceV().down().reverse().label('12 V', loc='bot')
    l2 = elm.Line().left().tox(v1.start)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r6).label('i$_x$', loc='top', color='#3b8dbf').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)
