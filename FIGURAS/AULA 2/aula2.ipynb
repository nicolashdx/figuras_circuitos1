# %%
import schemdraw
import schemdraw.elements as elm

from PIL import Image
import matplotlib.pyplot as plt

import os

# %%
def next_name(folder_path):
    # Listar todos os arquivos na pasta que terminam com .png
    png_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]
    
    if not png_files:
        # Se não houver arquivos JPG, o primeiro nome será "1.png"
        return "1.png"
    
    # Remover a extensão e converter para inteiro para ordenar
    numbers = [int(os.path.splitext(f)[0]) for f in png_files]
    
    # Encontrar o maior número e adicionar 1
    next_number = max(numbers) + 1
    
    # Retornar o próximo nome de arquivo
    return f"{next_number}.png"

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)
    D1 = elm.Ic(pins=[elm.IcPin(name='2', side='l', slot='1/2', anchorname='B', color='#3b8dbf'),
                      elm.IcPin(name='1', side='l', slot='2/2', anchorname='A', color='#3b8dbf'),
                      ], pinspacing=1.5).label('v', loc='left', ofst=(-1.15, 0), color='#3b8dbf', fontsize=16).fill('lightgrey')
    

    l1 = elm.Line(length=.5).left().at(D1.A).label('+', loc='left', color='#3b8dbf',fontsize=16)
    l2 = elm.Line().left().at(D1.B).label('-', loc='left', color='#3b8dbf',fontsize=28)

    A1 = elm.CurrentLabel(top=False, ofst=-.2, length=.8, reverse=True).at([l1.end[0]+0.4, l1.end[1]+.1]).label('i', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
cor = "#3b8dbf"

with schemdraw.Drawing() as d:
    d.config(unit=4.5)
    
    d1 = elm.Dot().color(cor).label('a', loc='right', color=cor, fontsize=16)
    V1 = elm.SourceV().reverse().down().color(cor).label("V$_S$", loc="top", color=cor, fontsize=16)
    d2 = elm.Dot().color(cor).label('b', loc='right', color=cor, fontsize=16)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
cor = "#ed7d31"

with schemdraw.Drawing() as d:
    d.config(unit=4.5)
    
    d1 = elm.Dot().color(cor).label('a', loc='right', color=cor, fontsize=16)
    V1 = elm.SourceI().reverse().down().color(cor).label("I$_S$", loc="top", color=cor, fontsize=16)
    d2 = elm.Dot().color(cor).label('b', loc='right', color=cor, fontsize=16)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
cor = "#000000"

with schemdraw.Drawing() as d:
    d.config(unit=4.5)
    
    d1 = elm.Dot().color(cor)
    V1 = elm.SourceControlledV().reverse().down().color(cor).label("V$_S$=µV$_X$", loc="top", color=cor, fontsize=14)
    d2 = elm.Dot().color(cor).label("(a)", loc='bot', ofst=.4, fontsize=18)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
cor = "#000000"

with schemdraw.Drawing() as d:
    d.config(unit=4.5)
    
    d1 = elm.Dot().color(cor)
    V1 = elm.SourceControlledI().reverse().down().color(cor).label("I$_S$=αV$_X$", loc="top", color=cor, fontsize=14)
    d2 = elm.Dot().color(cor).label("(b)", loc='bot', ofst=.4, fontsize=18)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
cor = "#000000"

with schemdraw.Drawing() as d:
    d.config(unit=4.5)
    
    d1 = elm.Dot().color(cor)
    V1 = elm.SourceControlledV().reverse().down().color(cor).label("V$_S$=ρI$_X$", loc="top", color=cor, fontsize=14)
    d2 = elm.Dot().color(cor).label("(c)", loc='bot', ofst=.4, fontsize=18)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
cor = "#000000"

with schemdraw.Drawing() as d:
    d.config(unit=4.5)
    
    d1 = elm.Dot().color(cor)
    V1 = elm.SourceControlledI().reverse().down().color(cor).label("I$_S$=βI$_X$", loc="top", color=cor, fontsize=14)
    d2 = elm.Dot().color(cor).label("(d)", loc='bot', ofst=.4, fontsize=18)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceV().up().label("10 V", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=1.5)
    d1 = elm.Dot().label('a', loc='top')
    l4 = elm.Line().right()

    l5 = elm.Line().down()
    d.config(unit=0.75)
    V1 = elm.SourceV().down().reverse().label("10 V", loc='bot')
    l6 = elm.Line().down()

    l7 = elm.Line().left()
    d.config(unit=1.5)
    d2 = elm.Dot().label('b', loc='bot').label("(a)", loc='bot', ofst=.8, fontsize=18)
    l8 = elm.Line().left()


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    I1 = elm.SourceI().up().label("5 A", loc='bot')
    l2 = elm.Line().up()
    d1 = elm.Dot().label('a', loc='top')

    d.config(unit=3)
    I2 = elm.SourceI().right().label("5 A", loc='top')
    
    d2 = elm.Dot().label('b', loc='top')
    d.config(unit=2.5)
    l3 = elm.Line().down()

    l3 = elm.Line().left().label("(b)", loc='bot', ofst=.8, fontsize=18)
    d.config(unit=3)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceV().up().label("10 V", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=1.5)
    d1 = elm.Dot().label('a', loc='top')
    l4 = elm.Line().right()

    l5 = elm.Line().down()
    d.config(unit=0.75)
    V1 = elm.SourceV().down().reverse().label("5 V", loc='bot')
    l6 = elm.Line().down()

    l7 = elm.Line().left()
    d.config(unit=1.5)
    d2 = elm.Dot().label('b', loc='bot').label("(c)", loc='bot', ofst=.8, fontsize=18)
    l8 = elm.Line().left()


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    I1 = elm.SourceI().up().label("5 A", loc='bot')
    l2 = elm.Line().up()
    d1 = elm.Dot().label('a', loc='top')

    d.config(unit=3)
    I2 = elm.SourceI().right().label("2 A", loc='top')
    
    d2 = elm.Dot().label('b', loc='top')
    d.config(unit=2.5)
    l3 = elm.Line().down()

    l3 = elm.Line().left().label("(d)", loc='bot', ofst=.8, fontsize=18)
    d.config(unit=3)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    d2 = elm.Dot().label('b', loc='bot')
    l1 = elm.Line().up()
    I1 = elm.SourceI().up().label("5 A", loc='bot')
    l2 = elm.Line().up()
    d1 = elm.Dot().label('a', loc='top')

    d.config(unit=3)
    I2 = elm.SourceI().right().label("2 A", loc='top')
    
    d2 = elm.Dot().label('b', loc='top')
    d.config(unit=2.5)
    l3 = elm.Line().down()

    l3 = elm.Line().left().label("(e)", loc='bot', ofst=.8, fontsize=18)
    d.config(unit=3)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceV().up().label("V$_X$=5 V", loc='bot', ofst=(-.8, .35))
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=1.5)
    d1 = elm.Dot().label('a', loc='top')
    l4 = elm.Line().right()

    l5 = elm.Line().down()
    d.config(unit=0.75)
    V1 = elm.SourceControlledV().down().reverse().label("V$_S$=3V$_X$", loc='top', ofst=(-.8,.35))
    l6 = elm.Line().down()

    l7 = elm.Line().left()
    d.config(unit=1.5)
    d2 = elm.Dot().label('b', loc='bot').label("(a)", loc='bot', ofst=.8, fontsize=18)
    l8 = elm.Line().left()


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceV().up().label("V$_X$=5 V", loc='bot', ofst=(-.8, .35))
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=1.5)
    d1 = elm.Dot().label('a', loc='top')
    l4 = elm.Line().right()

    l5 = elm.Line().down()
    d.config(unit=0.75)
    V1 = elm.SourceControlledI().down().reverse().label("I$_S$=3V$_X$", loc='top', ofst=(-.8,.35))
    l6 = elm.Line().down()

    l7 = elm.Line().left()
    d.config(unit=1.5)
    d2 = elm.Dot().label('b', loc='bot').label("(b)", loc='bot', ofst=.8, fontsize=18)
    l8 = elm.Line().left()


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceI().up().label("I$_X$=2 A", loc='bot', ofst=(-.8, .35))
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=1.5)
    d1 = elm.Dot().label('a', loc='top')
    l4 = elm.Line().right()

    l5 = elm.Line().down()
    d.config(unit=0.75)
    V1 = elm.SourceControlledV().down().reverse().label("V$_S$=4I$_X$", loc='top', ofst=(-.8,.35))
    l6 = elm.Line().down()

    l7 = elm.Line().left()
    d.config(unit=1.5)
    d2 = elm.Dot().label('b', loc='bot').label("(c)", loc='bot', ofst=.8, fontsize=18)
    l8 = elm.Line().left()


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceI().up().label("I$_X$=2 A", loc='bot', ofst=(-.8, .35))
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=1.5)
    d1 = elm.Dot().label('a', loc='top')
    l4 = elm.Line().right()

    l5 = elm.Line().down()
    d.config(unit=0.75)
    V1 = elm.SourceControlledI().down().reverse().label("I$_S$=3I$_X$", loc='top', ofst=(-.8,.35))
    l6 = elm.Line().down()

    l7 = elm.Line().left()
    d.config(unit=1.5)
    d2 = elm.Dot().label('b', loc='bot').label("(d)", loc='bot', ofst=.8, fontsize=18)
    l8 = elm.Line().left()


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4)

    d1 = elm.Dot()
    R = elm.Resistor().right().label("R", loc="top", fontsize=24)
    d2 = elm.Dot()
    

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
cor = "#3b8dbf"

with schemdraw.Drawing() as d:
    d.config(unit=4.5)

    d1 = elm.Dot().color(cor).label('+', loc='left', fontsize=24, ofst=(-.6,-.15))
    R = elm.Resistor().down().label("R", loc="bot", fontsize=24).label('V',fontsize=24, ofst=(.45)).color(cor)
    d2 = elm.Dot().color(cor).label('-', loc='left', fontsize=36, ofst=(.6))

    A1 = elm.CurrentLabel(top=True, ofst=-.2, length=1, reverse=False).at([R.start[0]+0.5, R.start[1]-1]).label('i', loc='bot', fontsize=18).color(cor)


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
cor = "#ed7d31"

with schemdraw.Drawing() as d:
    d.config(unit=4.5)

    d1 = elm.Dot().color(cor).label('+', loc='left', fontsize=24, ofst=(-.6,-.15))
    R = elm.Resistor().down().label("R", loc="bot", fontsize=24).label('V',fontsize=24, ofst=(.45)).color(cor)
    d2 = elm.Dot().color(cor).label('-', loc='left', fontsize=36, ofst=(.6))

    A1 = elm.CurrentLabel(top=True, ofst=-.2, length=1, reverse=True).at([R.start[0]+0.5, R.start[1]-1]).label('i', loc='bot', fontsize=18).color(cor)


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceI().up().label("1 A", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right().label('+', loc='center', ofst=(0, -.3), color="gray")
    d.config(unit=3.5)

    l5 = elm.Line().down()
    d.config(unit=0.75)
    R = elm.Resistor().down().label("8 Ω", loc='top').label('V$_a$', loc='top', ofst=(0,-1.25), color='gray')
    l6 = elm.Line().down()

    l7 = elm.Line().left().label('-', loc='center', fontsize=21, ofst=(0, -.3), color='gray').label("(a)", loc='center', ofst=(0,.6), fontsize=18)
    d.config(unit=3.5)


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceV().up().label("50 V", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=3.5)

    l5 = elm.Line().down()
    d.config(unit=0.75)
    R = elm.Resistor().down().label("0,2 S", loc='top')
    l6 = elm.Line().down()

    l7 = elm.Line().left().label("(b)", loc='center', ofst=(0,.6), fontsize=18)
    d.config(unit=3.5)


    A1 = elm.CurrentLabel(top=True, ofst=.3, length=1, reverse=False).at(R).label('i$_b$', loc='bot', fontsize=18).color('gray')


    d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceI().up().reverse().label("1 A", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right().label('+', loc='center', ofst=(0, -.3), color="gray")
    d.config(unit=3.5)

    l5 = elm.Line().down()
    d.config(unit=0.75)
    R = elm.Resistor().down().label("20 Ω", loc='top').label('V$_c$', loc='top', ofst=(0,-1.25), color='gray')
    l6 = elm.Line().down()

    l7 = elm.Line().left().label('-', loc='center', fontsize=21, ofst=(0, -.3), color='gray').label("(c)", loc='center', ofst=(0,.6), fontsize=18)
    d.config(unit=3.5)


    d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceV().up().label("50 V", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=3.5)

    l5 = elm.Line().down()
    d.config(unit=0.75)
    R = elm.Resistor().down().label("25 Ω", loc='top')
    l6 = elm.Line().down()

    l7 = elm.Line().left().label("(d)", loc='center', ofst=(0,.6), fontsize=18)
    d.config(unit=3.5)


    A1 = elm.CurrentLabel(top=True, ofst=.3, length=1, reverse=True).at(R).label('i$_d$', loc='bot', fontsize=18).color('gray')


    d.save(next_name("./"), dpi=600, transparent=True)
