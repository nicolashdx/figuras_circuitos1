# %%
import schemdraw
import schemdraw.elements as elm

from PIL import Image
import matplotlib.pyplot as plt

import os

# %%
def next_name(folder_path):
    # Listar todos os arquivos na pasta que terminam com .png
    png_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]
    
    if not png_files:
        # Se não houver arquivos JPG, o primeiro nome será "1.png"
        return "1.png"
    
    # Remover a extensão e converter para inteiro para ordenar
    numbers = [int(os.path.splitext(f)[0]) for f in png_files]
    
    # Encontrar o maior número e adicionar 1
    next_number = max(numbers) + 1
    
    # Retornar o próximo nome de arquivo
    return f"{next_number}.png"

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    V2 = elm.SourceV().label('V$_2$')
    d6 = elm.Dot().label('c', loc='left')
    V1 = elm.SourceV().label('V$_1$')
    
    d1 = elm.Dot().label('a', loc='left')
    r1 = elm.Resistor().right().label('R$_1$').length(6)
    
    d2 = elm.Dot().label('b', loc='top')
    
    d.push()
    r5 = elm.Resistor().down().label('R$_5$', loc='bot')
    d3 = elm.Dot().label('e', loc='right')
    
    d.push()
    r3 = elm.Resistor().left().label('R$_3$')
    d4 = elm.Dot().label('d', loc='top')
    r2 = elm.Resistor().left().label('R$_2$')
    d.pop()

    r6 = elm.Resistor().down().label('R$_6$', loc='bot')
    d5 = elm.Dot().label('g', loc='bot')

    r4 = elm.Resistor().left().label('R$_4$', loc='top').length(6)
    d5 = elm.Dot().label('f', loc='bot')
    d.pop()

    l1 = elm.Line().right().length(2)
    d.push()
    elm.Dot()
    r7 = elm.Resistor().down().label('R$_7$', loc='bot').length(6)
    elm.Dot()
    d.pop()

    l2 = elm.Line().right().length(2)
    i1 = elm.SourceI().down().length(6).reverse().label('I$_3$', loc='bot')
    
    l3 = elm.Line().left().tox(r6.end)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=16)
    l1 = elm.Line().right()
    d1 = elm.Dot().label('a', loc='top')
    
    r1 = elm.Resistor().right().label('R$_1$')

    r2 = elm.Resistor().right().label('R$_2$')

    r3 = elm.Resistor().right().label('R$_3$')

    r4 = elm.Resistor().down().label('R$_4$', loc='bot').label(['+', 'V$_s$', '-'], loc='top', ofst=(0, -7.5), color='#3b8dbf')

    r5 = elm.Resistor().left().label('R$_5$', loc='bot')

    r5 = elm.Resistor().left().label('R$_6$', loc='bot')

    r5 = elm.Resistor().left().label('R$_7$', loc='bot')
    d2 = elm.Dot().label('h', loc='bot')

    l2 = elm.Line().left()

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=True).at((l1.start[0]+.75, l1.start[1])).label('i$_s$', loc='top', color='#3b8dbf').color('#3b8dbf')

    rect = elm.Rect(corner1=(r1.start[0]-11, r1.start[1]+1), corner2=(r5.start[0]-5.5, r5.start[1]-1), fill='#eaf6fe')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=16)
    l1 = elm.Line().right()
    d1 = elm.Dot().label('a', loc='top')
    
    d.config(unit=1)
    l3 = elm.Line().right()

    d.push()
    d.config(unit=2)
    r1 = elm.Resistor().down().label('R$_1$', loc='bot')
    d.pop()

    l4 = elm.Line().right()

    d.push()
    r2 = elm.Resistor().down().label('R$_2$', loc='bot')
    d.pop()

    l5 = elm.Line().right()
    d.push()
    r3 = elm.Resistor().down().label('R$_3$', loc='bot')
    d.pop()

    l6 = elm.Line().right()
    r4 = elm.Resistor().down().label('R$_4$', loc='bot')

    l2 = elm.Line().left().tox(l1.start)
    d2 = elm.Dot().label('b', loc='bot').at((l1.end[0], l2.start[1]))

    v1 = elm.SourceV().up().label('V$_s$', loc='top').at(l2.end).color((0, 0, 0, 0)).label(['-', 'V$_s$', '+'], loc='top', ofst=(0, -.75), color='#3b8dbf')


    A1 = elm.CurrentLabel(top=True, ofst=.3, length=1, reverse=False).at((l1.start[0]+.75, l1.start[1])).label('i$_s$', loc='top', color='#3b8dbf').color('#3b8dbf').theta(0)

    rect = elm.Rect(corner1=(r1.start[0]-5.75, r1.start[1]-1.5), corner2=(r5.start[0]-3.25, r5.start[1]-8), fill='#eaf6fe')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=16)
    lt = elm.Line().right()
    d1 = elm.Dot().label('a', loc='top')
    
    d.config(unit=.75)
    l1 = elm.Line().right()

    r1 = elm.Resistor().down().label('R$_e$$_q$', loc='bot').label(['+', 'V$_s$', '-'], loc='top', ofst=(0, -2.25), color='#3b8dbf')
    d.config(unit=2)

    l2 = elm.Line().left()
    d.config(unit=.75)

    d2 = elm.Dot().label('h', loc='bot')

    d.config(unit=2)
    lb = elm.Line().left()

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=True).at((lt.start[0]+.75, lt.start[1])).label('i$_s$', loc='top', color='#3b8dbf').color('#3b8dbf')

    rect = elm.Rect(corner1=(r1.start[0]-6.75, r1.start[1]+.75), corner2=(r1.end[0]-4.25, r1.end[1]-.75), fill='#eaf6fe')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18, color='#c56423')

    d1 = elm.Dot().label('a', loc='left')
    r1 = elm.Resistor().label('R$_1$', loc='bot').theta(-30)
    d2 = elm.Dot()
    d.push()
    r2 = elm.Resistor().label('R$_2$', loc='bot').theta(30)
    d3 = elm.Dot().label('b', loc='right')
    d.pop()
    r3 = elm.Resistor().label('R$_3$', loc='top').down()
    d4 = elm.Dot().label('c', loc='bot')
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4, fontsize=18, color='#365da4')

    d1 = elm.Dot().label('a', loc='left')
    d.push()
    r3 = elm.Resistor().label('R$_c$', loc='top').right()
    d2 = elm.Dot().label('b', loc='right')
    r1 = elm.Resistor().label('R$_a$', loc='bot').theta(-120)
    d3 = elm.Dot().label('c', loc='bot')
    d.pop()
    r2 = elm.Resistor().label('R$_b$', loc='bot').theta(-60)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('V$_s$')

    r = elm.Resistor().right().label('R', loc='top')

    d1 = elm.Dot().label('a', loc='right')

    l1 = elm.Line().down().length(1)
    rl = elm.Resistor().down().label('R$_L$', loc='bot').length(1).color('#3b8dbf')
    l2 = elm.Line().down().length(1)

    d2 = elm.Dot().label('b', loc='right')

    l3 = elm.Line().tox(v1.start)

    A1 = elm.CurrentLabel(top=True, ofst=-.75, length=.7, reverse=True).at((rl.start[0]-1, rl.start[1]+.5)).label('i$_L$', loc='top', color='#c00000').color('#c00000').theta(90)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    i1 = elm.SourceI().label('i$_s$')

    l10 = elm.Line().right()
    
    d.push()
    elm.Dot()
    r = elm.Resistor().down().label('R', loc='top')
    elm.Dot()
    d.pop()

    l11 = elm.Line().right()
    d1 = elm.Dot().label('a', loc='right')

    l1 = elm.Line().down().length(1)
    rl = elm.Resistor().down().label('R$_L$', loc='bot').length(1).color('#3b8dbf')
    l2 = elm.Line().down().length(1)

    d2 = elm.Dot().label('b', loc='right')

    l3 = elm.Line().tox(v1.start)

    A1 = elm.CurrentLabel(top=True, ofst=-.75, length=.7, reverse=True).at((rl.start[0]-1, rl.start[1]+.5)).label('i$_L$', loc='top', color='#c00000').color('#c00000').theta(90)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('6 V')
    r1 = elm.Resistor().right().label('4 Ω')
    d1 = elm.Dot()

    d.push()
    r2 = elm.Resistor().down().label('30 Ω')
    d2 = elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('6 Ω')
    d.push()
    r4 = elm.Resistor().down().label('20 Ω', loc='bot')
    elm.Dot()
    d.pop()

    d3 = elm.Dot()
    r5 = elm.Resistor().right().label('5 Ω')
    i2 = elm.SourceV().down().reverse().label('40V', loc='bot')
    
    l1 = elm.Line().left()
    r6 = elm.Resistor().left().label('10 Ω')
    l2 = elm.Line().left()
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('6 V')
    r1 = elm.Resistor().right().label('4 Ω')
    d1 = elm.Dot()

    d.push()
    r2 = elm.Resistor().down().label('30 Ω')
    d2 = elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('6 Ω')
    d.push()
    elm.Dot()
    r4 = elm.Resistor().down().label('20 Ω', loc='bot')
    elm.Dot()
    d.pop()

    l3 = elm.Line().right()
    
    d.push()
    d3 = elm.Dot()
    r5 = elm.Resistor().down().label('5 Ω', loc='bot')
    elm.Dot()
    d.pop()

    l4 = elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('8 A', loc='bot')
    
    
    l1 = elm.Line().tox(r4.start)
    r6 = elm.Resistor().left().label('10 Ω')
    l2 = elm.Line().left()
    
    rect1 = elm.Rect(corner1=(l3.center[0]+.25, l3.center[1]+.75), corner2=(i2.end[0]+1.75, i2.end[1]-.75), fill='#d4edfc', lw=0).theta(0)
    rect2 = elm.Rect(corner1=(r3.center[0]+.75, r3.center[1]+.75), corner2=(l3.center[0]+.25, i2.end[1]-.75), fill='#eaf6fe', lw=0).theta(0)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('6 V')
    r1 = elm.Resistor().right().label('4 Ω')
    d1 = elm.Dot()

    d.push()
    r2 = elm.Resistor().down().label('30 Ω')
    d2 = elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('6 Ω')

    r5 = elm.Resistor().right().label('4 Ω')
    i2 = elm.SourceV().down().reverse().label('32V', loc='bot')
    
    l1 = elm.Line().left()
    r6 = elm.Resistor().left().label('10 Ω')
    l2 = elm.Line().left()
    
    rect1 = elm.Rect(corner1=(r4.start[0], r4.start[1]+1), corner2=(i2.end[0]+1.75, i2.end[1]-.75), fill='#d4edfc', lw=0).theta(0)
    rect2 = elm.Rect(corner1=(r3.start[0]+.75, r3.start[1]+1), corner2=(r4.start[0], i2.end[1]-.75), fill='#eaf6fe', lw=0).theta(0)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('6 V')
    r1 = elm.Resistor().right().label('4 Ω')
    d1 = elm.Dot()

    d.push()
    r2 = elm.Resistor().down().label('30 Ω', loc='bot')
    d2 = elm.Dot()
    d.pop()

    elm.Line().right()

    d.push()
    elm.Dot()
    r3 = elm.Resistor().down().label('20 Ω', loc='bot')
    elm.Dot()
    d.pop()

    elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('1,6 A', loc='bot')
    l2 = elm.Line().tox(v1.start)
    
    rect1 = elm.Rect(corner1=(r3.start[0]-1, r3.start[1]+.75), corner2=(i2.end[0]+1.75, i2.end[1]-.75), fill='#d4edfc', lw=0).theta(0)
    rect2 = elm.Rect(corner1=(r2.start[0]-.75, r2.start[1]+.75), corner2=(r3.start[0]-1, i2.end[1]-.75), fill='#eaf6fe', lw=0).theta(0)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('6 V')
    r1 = elm.Resistor().right().label('4 Ω')

    r2 = elm.Resistor().right().label('12 Ω', loc='top')

    i2 = elm.SourceV().down().reverse().label('19,2 V', loc='bot')
    l2 = elm.Line().tox(v1.start)

    rect1 = elm.Rect(corner1=(r2.start[0], r2.start[1]+1), corner2=(i2.end[0]+2.5, i2.end[1]-.75), fill='#d4edfc', lw=0).theta(0)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2, fontsize=18)
    
    v1 = elm.SourceV().label('V$_s$', loc='bot').length(3)

    l1 = elm.Line().right()

    d.push()
    d1 = elm.Dot()
    r1 = elm.Resistor().down().label('R$_p$', loc='bot').length(3)
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('R', loc='top').length(2.5)
    
    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0)).length(3)
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('V$_s$', loc='bot')

    r2 = elm.Resistor().right().label('R', loc='top')
    
    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0))
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceI().label('i$_s$', loc='bot')
    r2 = elm.Resistor().right().label('R$_s$', loc='top')

    l1 = elm.Line().right().length(2)
    
    d.push()
    d1 = elm.Dot().at([l1.center[0]-.5, l1.center[1]])
    r1 = elm.Resistor().down().label('R', loc='bot')
    d2 = elm.Dot()
    d.pop()

    
    
    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0))
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceI().label('i$_s$', loc='bot')

    l1 = elm.Line().right().length(3.5)
    
    d.push()
    d1 = elm.Dot().at(l1.center)
    r1 = elm.Resistor().down().label('R', loc='bot')
    d2 = elm.Dot()
    d.pop()

    
    
    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0))
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('250 V', loc='top').length(4)
    l1 = elm.Line().right().length(2)

    elm.Dot()
    d.push()
    r1 = elm.Resistor().down().label('125 Ω', loc='bot').length(4)
    elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('25 Ω', loc='top')
    elm.Dot()
    d.push()
    i2 = elm.SourceI().down().label('8 A', loc='bot').length(2)
    r3 = elm.Resistor().down().label('10 Ω', loc='bot').length(2)
    elm.Dot()
    d.pop()

    l2 = elm.Line().right()
    elm.Dot()
    d.push()
    r4 = elm.Resistor().down().label('100 Ω', loc='bot').length(4).label(['+', 'v$_0$', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()

    r5 = elm.Resistor().right().label('5 Ω', loc='top')
    r6 = elm.Resistor().down().label('15 Ω', loc='bot').length(4)

    l3 = elm.Line().tox(v1.start)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    l1 = elm.Line().right().color((0,0,0,0))
    elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0,0,0,0))
    elm.Dot().label('b', loc='right')
    l3 = elm.Line().left().color((0,0,0,0))

    rect1 = elm.Rect(corner1=(l1.start[0]-1.25, l1.start[1]+3.75), corner2=(l3.start[0]+.75, l3.start[1]+2.25), fill='#d4edfc', lw=0).theta(0)

    rect1.label('''Uma rede resistiva\nque contém fontes\nindependentes\ne dependentes.''', loc='center', fontsize=16)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('V$_T$$_h$', loc='top')

    r2 = elm.Resistor().right().label('R$_T$$_h$', loc='top')
    
    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0))
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)

    rect1 = elm.Rect(corner1=(v1.end[0]-1.75, v1.end[1]+1), corner2=(l3.start[0]-.5, l3.start[1]-.5), fill='#d4edfc', lw=0).theta(0)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('32 V', loc='bot')

    r2 = elm.Resistor().right().label('8 Ω', loc='top').length(5)
    
    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0))
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)

    rect1 = elm.Rect(corner1=(v1.end[0]-.75, v1.end[1]+1), corner2=(l3.start[0]-.5, l3.start[1]-.5), fill='#d4edfc', lw=0).theta(0)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceI().label('4 A V', loc='bot')

    l1 = elm.Line().right().length(5)

    d.push()
    r2 = elm.Resistor().down().label('8 Ω', loc='bot').at(l1.center)
    d.pop()

    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0))
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)

    rect1 = elm.Rect(corner1=(v1.end[0]-.75, v1.end[1]+1), corner2=(l3.start[0]-.5, l3.start[1]-.5), fill='#d4edfc', lw=0).theta(0)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('25 V', loc='top')
    r1 = elm.Resistor().right().label('5 Ω', loc='top')

    elm.Dot()
    d.push()
    r2 = elm.Resistor().down().label('20 Ω', loc='top')
    elm.Dot()
    d.pop()

    l1 = elm.Line().right()
    elm.Dot()
    d.push()
    i2 = elm.SourceI().down().label('3 A', loc='top').reverse().label(['+', 'v$_1$', '-'], loc='bot', color='#3b8dbf')
    elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('4 Ω', loc='top')
    d1 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0,0,0,0)).label(['+', 'v$_a$$_b$', '-'], loc='bot', color='#3b8dbf')
    d2 = elm.Dot().label('b', loc='right')
    l3 = elm.Line().tox(v1.start)

    rect1 = elm.Rect(corner1=(v1.end[0]-2, v1.end[1]+1), corner2=(d2.start[0]-.5, d2.start[1]-.5), fill='#d4edfc', lw=0).theta(0)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('25 V', loc='top')
    r1 = elm.Resistor().right().label('5 Ω', loc='top')

    elm.Dot()
    d.push()
    r2 = elm.Resistor().down().label('20 Ω', loc='top')
    elm.Dot()
    d.pop()

    l1 = elm.Line().right()
    elm.Dot()
    d.push()
    i2 = elm.SourceI().down().label('3 A', loc='top').reverse().label(['+', 'v$_2$', '-'], loc='bot', color='#3b8dbf')
    elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('4 Ω', loc='top')
    d1 = elm.Dot().label('a', loc='top')
    l2 = elm.Line().down().color((0,0,0,0))
    d2 = elm.Dot().label('b', loc='bot')
    l3 = elm.Line().tox(v1.start)

    rect1 = elm.Rect(corner1=(v1.end[0]-2, v1.end[1]+1), corner2=(d2.start[0]-.5, d2.start[1]-.5), fill='#d4edfc', lw=0).theta(0)

    elm.Line().right().length(1).at(r3.end)
    l4 = elm.Line().down()
    elm.Line().left().length(1)

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=False).at(l4).label('i$_s$$_c$', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('32 V', loc='top')

    r2 = elm.Resistor().right().label('8 Ω', loc='top')
    
    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0))
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('25 V', loc='bot')
    r1 = elm.Resistor().right().label('5 Ω', loc='top')

    elm.Dot()
    d.push()
    r2 = elm.Resistor().down().label('20 Ω', loc='bot')
    elm.Dot()
    d.pop()

    l1 = elm.Line().right()
    elm.Dot()
    d.push()
    i2 = elm.SourceI().down().label('3 A', loc='bot').reverse()
    elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('4 Ω', loc='top')
    d1 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0,0,0,0))
    d2 = elm.Dot().label('b', loc='right')
    l3 = elm.Line().tox(v1.start)

    rect1 = elm.Rect(corner1=(v1.end[0]-.75, v1.end[1]+1), corner2=(d2.start[0]-.5, d2.start[1]-.5), fill='#eaf6fe', lw=0).theta(0)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    i1 = elm.SourceI().label('8 A', loc='top')
    elm.Line().right()
    elm.Dot()
    d.push()
    r1 = elm.Resistor().down().label('5 Ω', loc='top')
    elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('20 Ω', loc='bot')
   
    d1 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0,0,0,0))
    d2 = elm.Dot().label('b', loc='right')

    elm.Line().tox(i1.start)

    rect1 = elm.Rect(corner1=(v1.end[0]-1.75, v1.end[1]+1), corner2=(d2.start[0]-.5, d2.start[1]-.5), fill='#eaf6fe', lw=0).theta(0)
    rect2 = elm.Rect(corner1=(v1.end[0]-1.75, v1.end[1]+1), corner2=(r1.end[0]+.75, r1.end[1]-.5), fill='#d4edfc', lw=0).theta(0)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('32 V', loc='bot')

    r2 = elm.Resistor().right().label('8 Ω', loc='top').length(5)
    
    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0))
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)

    rect1 = elm.Rect(corner1=(v1.end[0]-.75, v1.end[1]+1), corner2=(l3.start[0]-.5, l3.start[1]-.5), fill='#d4edfc', lw=0).theta(0)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    l1 = elm.Line().up()

    r1 = elm.Resistor().right().label('5 Ω', loc='top')
    
    elm.Dot()
    d.push()
    r2 = elm.Resistor().down().label('20 Ω', loc='top')
    elm.Dot()
    d.pop()
    
    r3 = elm.Resistor().right().label('4 Ω', loc='top')
    d3 = elm.Dot().label('a', loc='right')
    l2 = elm.Line().down().color((0, 0, 0, 0))
    d4 = elm.Dot().label('b', loc='right')
    
    l3 = elm.Line().tox(v1.start)

    rect1 = elm.Rect(corner1=(v1.end[0]-.75, v1.end[1]+1), corner2=(l3.start[0]-.5, l3.start[1]-.5), fill='#d4edfc', lw=0).theta(0)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at((l2.center[0]+1, l2.center[1])).label('R$_a$$_b$', loc='right', ofst=(-.25, 0))
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    l1 = elm.Line().right().color((0,0,0,0))
    elm.Dot()
    l2 = elm.Line().down().color((0,0,0,0))
    elm.Dot()
    l3 = elm.Line().left().color((0,0,0,0))

    d.push()
    elm.Line().right().at(l2.start)
    i = elm.SourceI().down().reverse().label('i $_T$', loc='bot', color='red').label(['+', 'v$_T$', '-'], loc='top', color='#3b8dbf', ofst=.5)
    i.segments[2].color = 'red'
    elm.Line().left()
    d.pop()


    rect1 = elm.Rect(corner1=(l1.start[0]-1.25, l1.start[1]+3.75), corner2=(l3.start[0]+.75, l3.start[1]+2.25), fill='#d4edfc', lw=0).theta(0)

    rect1.label(f'''Uma rede resistiva\nque contém fontes\n{''.join(c + '\u0336' for c in 'independentes ')}\ne dependentes.''', loc='center', fontsize=16)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label("24 V", loc='top')
    elm.Dot()

    d.push()
    r1 = elm.Resistor().right().length(4).label('2 Ω', loc='top')
    d.pop()

    elm.Line().up().length(2)
    i2 = elm.SourceControlledI().right().reverse().length(4).label('3 i$_x$', loc='top')
    elm.Line().down().length(2)

    elm.Dot()

    d.push()
    i3 = elm.SourceI().down().label("4 A", loc='top')
    elm.Dot()
    d.pop()

    elm.Line().right()
    elm.Dot()
    
    d.push()
    r2 = elm.Resistor().down().label('8 Ω', loc='bot')
    elm.Dot()
    d.pop()

    elm.Line().right()
    elm.Dot().label('a', loc='right')
    elm.Line().down().color((0,0,0,0))
    elm.Dot().label('b', loc='right')
    elm.Line().tox(v1.start)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r2).label('i$_x$', loc='top').color('#3b8dbf')
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label("12 V", loc='top', color='#3b8dbf')
    v1.segments[2].color = '#3b8dbf'
    v1.segments[3].color = '#3b8dbf'
    v1.segments[4].color = '#3b8dbf'

    r1 = elm.Resistor().right().label('2 Ω', loc='top').label(['+', 'v$_x$', '-'], loc='bot', color='#3b8dbf')

    elm.Dot()

    d.push()
    r2 = elm.Resistor().down().label('4 Ω', loc='bot')
    elm.Dot()
    d.pop()

    d.push()
    i2 = elm.SourceI().right().label("3 A", loc='top', color='red')
    i2.segments[2].color = 'red'
    d.pop()

    elm.Line().up().length(2)
    r3 = elm.Resistor().right().label('8 Ω', loc='top')
    elm.Line().down().length(2)

    elm.Dot()

    r4 = elm.Resistor().down().label('1 Ω', loc='bot')

    v3 = elm.SourceControlledV().left().label('5 v$_x$', loc='bot', color='#3b8dbf')
    v3.segments[1].color = '#3b8dbf'
    v3.segments[2].color = '#3b8dbf'
    v3.segments[3].color = '#3b8dbf'

    elm.Line().tox(v1.start)
    
    #d.save(next_name("./"), dpi=600, transparent=True)
