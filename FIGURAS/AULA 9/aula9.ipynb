# %%
import schemdraw
import schemdraw.elements as elm

from PIL import Image
import matplotlib.pyplot as plt

import os

# %%
def next_name(folder_path):
    # Listar todos os arquivos na pasta que terminam com .png
    png_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]
    
    if not png_files:
        # Se não houver arquivos JPG, o primeiro nome será "1.png"
        return "1.png"
    
    # Remover a extensão e converter para inteiro para ordenar
    numbers = [int(os.path.splitext(f)[0]) for f in png_files]
    
    # Encontrar o maior número e adicionar 1
    next_number = max(numbers) + 1
    
    # Retornar o próximo nome de arquivo
    return f"{next_number}.png"

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    l1 = elm.Line().right().color((0,0,0,0))
    elm.Dot().label('a', loc='left')
    l2 = elm.Line().down().color((0,0,0,0))
    elm.Dot().label('b', loc='left')
    l3 = elm.Line().left().color((0,0,0,0))

    d.push()
    elm.Line().right().at(l2.start).length(2.5)
    r = elm.Resistor().down().label('R$_L$', loc='bot')
    elm.Line().left().length(2.5)
    d.pop()


    rect1 = elm.Rect(corner1=(l1.start[0]-1.25, l1.start[1]+3.75), corner2=(l3.start[0]+.75, l3.start[1]+2.25), fill='#d4edfc', lw=0).theta(0)

    rect1.label(f'''Uma rede resistiva\nque contém fontes\nindependentes\ne dependentes.''', loc='center', fontsize=16)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    d.push()
    v1 = elm.SourceV().down().label('V$_T$$_h$', loc='bot').reverse().length(2.75)
    d.pop()

    rth = elm.Resistor().right().label('R$_T$$_h$', loc='top')
    elm.Dot().label('a', loc='top')
    l2 = elm.Line().down().color((0,0,0,0)).length(2.75)
    elm.Dot().label('b', loc='bot')
    l3 = elm.Line().left()

    d.push()
    elm.Line().right().at(l2.start).length(2.5)
    r = elm.Resistor().down().label('R$_L$', loc='bot').length(2.75)
    elm.Line().left().length(2.5)
    d.pop()

    rect1 = elm.Rect(corner1=(l1.start[0]-1.25, l1.start[1]+3.75), corner2=(l3.start[0]+.75, l3.start[1]+2.25), fill='#d4edfc', lw=0).theta(0)
    
    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r).label('i', loc='top').color('#3b8dbf')
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    d.push()
    v1 = elm.SourceV().down().label('360 V', loc='top').reverse().length(2.75)
    d.pop()

    rth = elm.Resistor().right().label('30 Ω', loc='top')
    elm.Dot()
    l2 = elm.Resistor().down().label('150 Ω', loc='top').length(2.75)
    elm.Dot()
    l3 = elm.Line().left()

    d.push()
    l4 = elm.Line().right().at(l2.start).length(2.5)
    r = elm.Resistor().down().label('R$_L$', loc='bot').length(2.75)
    l5 = elm.Line().left().length(2.5)
    d.pop()
    
    d.push()
    elm.Dot().label('a', loc='top').at(l4.center)
    elm.Dot().label('b', loc='bot').at(l5.center)
    d.pop()

    rect1 = elm.Rect(corner1=(l1.start[0]-2.25, l1.start[1]+3.75), corner2=(l3.start[0]+.75, l3.start[1]+2.25), fill='#d4edfc', lw=0).theta(0)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('120 V', loc='top')
    r1 = elm.Resistor().right().label('6 Ω', loc='top')

    elm.Dot()
    d.push()
    r2 = elm.Resistor().down().label('3 Ω', loc='bot')
    elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('2 Ω', loc='top')

    elm.Dot()
    d.push()
    r4 = elm.Resistor().down().label('4 Ω', loc='bot')
    elm.Dot()
    d.pop()

    elm.Line().right()
    i2 = elm.SourceI().down().label('12 A', loc='bot')
    elm.Line().tox(v1.start)
    
    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r1).label('i$_1$', loc='bot').color('#3b8dbf')
    A2 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r2).label('i$_2$', loc='top').color('#3b8dbf')
    A3 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r3).label('i$_3$', loc='bot').color('#3b8dbf')
    A4 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r4).label('i$_4$', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('120 V', loc='top')
    r1 = elm.Resistor().right().label('6 Ω', loc='top')

    elm.Dot()
    d.push()
    r2 = elm.Resistor().down().label('3 Ω', loc='bot')
    elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('2 Ω', loc='top')

    elm.Dot()
    d.push()
    r4 = elm.Resistor().down().label('4 Ω', loc='bot')
    elm.Dot()
    d.pop()

    elm.Line().right()
    elm.Dot()
    i2 = elm.SourceI().down().label('12 A', loc='bot').color((0,0,0,0))
    elm.Dot()
    elm.Line().tox(v1.start)
    
    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r1).label("i'$_1$", loc='bot').color('#3b8dbf')
    A2 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r2).label("i'$_2$", loc='top').color('#3b8dbf')
    A3 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r3).label("i'$_3$", loc='bot').color('#3b8dbf')
    A4 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r4).label("i'$_4$", loc='top').color('#3b8dbf')

    elm.GroundSignal().at(r2.end).fill('black')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    elm.Line().up()
    r1 = elm.Resistor().right().label('6 Ω', loc='top')

    elm.Dot()
    d.push()
    r2 = elm.Resistor().down().label('3 Ω', loc='bot')
    elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('2 Ω', loc='top')

    elm.Dot()
    d.push()
    r4 = elm.Resistor().down().label('4 Ω', loc='bot')
    elm.Dot()
    d.pop()

    elm.Line().right()
    i2 = elm.SourceI().down().label('12 A', loc='bot')
    elm.Line().tox(v1.start)
    
    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r1).label('i"$_1$', loc='bot').color('#3b8dbf')
    A2 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r2).label('i"$_2$', loc='top').color('#3b8dbf')
    A3 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r3).label('i"$_3$', loc='bot').color('#3b8dbf')
    A4 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r4).label('i"$_4$', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('10 V', loc='top')
    r1 = elm.Resistor().right().label('5 Ω', loc='top')

    elm.Dot()
    d.push()
    r2 = elm.Resistor().down().label('20 Ω', loc='bot').label(['+', 'v$_o$', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()

    i2 = elm.SourceControlledI().right().reverse().label('0,4 v$_Δ$', loc='top')

    elm.Dot()
    d.push()
    r4 = elm.Resistor().down().label('10 Ω', loc='bot').label(['+', 'v$_Δ$', '-'], loc='top', color='#3b8dbf')
    elm.Dot()
    d.pop()

    elm.Line().right()
    i2 = elm.SourceI().down().reverse().label('5 A', loc='bot')
    
    elm.Line().left()
    v3 = elm.SourceControlledV().left().reverse().label('2 i$_Δ$', loc='bot')
    elm.Line().left()
    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r1).label('i$_Δ$', loc='bot').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)
