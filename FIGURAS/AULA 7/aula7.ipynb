# %%
import schemdraw
import schemdraw.elements as elm

from PIL import Image
import matplotlib.pyplot as plt

import os

# %%
def next_name(folder_path):
    # Listar todos os arquivos na pasta que terminam com .png
    png_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]
    
    if not png_files:
        # Se não houver arquivos JPG, o primeiro nome será "1.png"
        return "1.png"
    
    # Remover a extensão e converter para inteiro para ordenar
    numbers = [int(os.path.splitext(f)[0]) for f in png_files]
    
    # Encontrar o maior número e adicionar 1
    next_number = max(numbers) + 1
    
    # Retornar o próximo nome de arquivo
    return f"{next_number}.png"

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    V2 = elm.SourceV().label('V$_2$')
    d6 = elm.Dot().label('c', loc='left')
    V1 = elm.SourceV().label('V$_1$')
    
    d1 = elm.Dot().label('a', loc='left')
    r1 = elm.Resistor().right().label('R$_1$').length(6)
    
    d2 = elm.Dot().label('b', loc='top')
    
    d.push()
    r5 = elm.Resistor().down().label('R$_5$', loc='bot')
    d3 = elm.Dot().label('e', loc='right')
    
    d.push()
    r3 = elm.Resistor().left().label('R$_3$')
    d4 = elm.Dot().label('d', loc='top')
    r2 = elm.Resistor().left().label('R$_2$')
    d.pop()

    r6 = elm.Resistor().down().label('R$_6$', loc='bot')
    d5 = elm.Dot().label('g', loc='bot')

    r4 = elm.Resistor().left().label('R$_4$', loc='top').length(6)
    d5 = elm.Dot().label('f', loc='bot')
    d.pop()

    l1 = elm.Line().right().length(2)
    d.push()
    elm.Dot()
    r7 = elm.Resistor().down().label('R$_7$', loc='bot').length(6)
    elm.Dot()
    d.pop()

    l2 = elm.Line().right().length(2)
    i1 = elm.SourceI().down().length(6).reverse().label('I$_3$', loc='bot')
    
    l3 = elm.Line().left().tox(r6.end)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3.5, fontsize=18)
    
    V2 = elm.SourceV().label('V$_s$')
    r1 = elm.Resistor().right().label('R$_1$').length(5)
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('R$_6$')
    d2 = elm.Dot()
    r5 = elm.Resistor().left().label('R$_5$').length(5)
    d.pop()

    r2 = elm.Resistor().right().label('R$_2$').length(5)
    d3 = elm.Dot()
    r3 = elm.Resistor().down().label('R$_3$', loc='bot')
    d3 = elm.Dot()
    r4 = elm.Resistor().left().label('R$_4$').length(5)

    r7 = elm.Resistor().endpoints(r6.start, [r4.center[0], r3.center[1]]).label('R$_7$')
    l1 = elm.Line().endpoints(r7.end, r3.end)

    r8 = elm.Resistor().endpoints(r3.start, [r4.center[0], r3.center[1]]).label('R$_8$', loc='bot')
    l1 = elm.Line().endpoints(r8.end, r4.end)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3.5, fontsize=18)
    
    V2 = elm.SourceV().label('V$_s$')
    r1 = elm.Resistor().right().label('R$_1$').length(5)
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('R$_6$')
    d2 = elm.Dot()
    r5 = elm.Resistor().left().label('R$_5$').length(5)
    d.pop()

    r2 = elm.Resistor().right().label('R$_2$').length(5)
    d3 = elm.Dot()
    r3 = elm.Resistor().down().label('R$_3$', loc='top')
    d3 = elm.Dot()
    r4 = elm.Resistor().left().label('R$_4$').length(5)

    l1 = elm.Line().endpoints(r3.start, [r4.center[0], r3.center[1]])

    r8 = elm.Resistor().label('R$_8$', loc='top').endpoints(l1.end, r4.end)
    
    l2 = elm.Line().at(r6.start).up().length(1.5)
    l3 = elm.Line().right().length(6.5)

    r7 = elm.Resistor().down().label('R$_7$').length(5)
    l4 = elm.Line().left().tox(r3.end)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3.5, fontsize=18)
    
    v1 = elm.SourceV().label('V$_s$')
    r1 = elm.Resistor().right().label('R$_1$')
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('R$_6$')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('R$_2$')
    d.push()
    r11 = elm.Resistor().down().label('R$_1$$_1$')
    elm.Dot()
    r5 = elm.Resistor().left().label('R$_5$', loc='bot')
    elm.Line().tox(v1.start)
    d.pop()

    d3 = elm.Dot()
    r3 = elm.Resistor().right().label('R$_3$', loc='top')
    l1 = elm.Line().down().length(3.5/2)
    elm.Dot()
    l2 = elm.Line().down().length(3.5/2)
    r4 = elm.Resistor().left().label('R$_4$', loc='bot')

    r7 = elm.Resistor().endpoints(r6.start, [r5.center[0], r11.center[1]]).label('R$_7$', ofst=(.25,0))
    l3 = elm.Line().endpoints(r7.end, r11.end)

    l4 = elm.Line().endpoints(r11.start, [r5.center[0], r11.center[1]])
    r9 = elm.Resistor().label('R$_9$', loc='top', ofst=(-.25,0)).endpoints(l4.end, r6.end)

    l5 = elm.Line().endpoints(r2.start, (7,2.625))
    r8 = elm.Resistor().endpoints(l5.end, l2.start).label('R$_8$', loc='top')

    l6 = elm.Line().endpoints(r6.end, (7,0.875))
    r10 = elm.Resistor().endpoints(l6.end, l2.start).label('R$_1$$_0$', loc='bot')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    V2 = elm.SourceV().label('V$_2$')
    d6 = elm.Dot().label('c', loc='left')
    V1 = elm.SourceV().label('V$_1$')
    
    d1 = elm.Dot().label('a', loc='left')
    r1 = elm.Resistor().right().label('R$_1$').length(6)
    
    d2 = elm.Dot().label('b', loc='top')
    
    d.push()
    r5 = elm.Resistor().down().label('R$_5$', loc='bot')
    d3 = elm.Dot().label('e', loc='right')
    
    d.push()
    r3 = elm.Resistor().left().label('R$_3$')
    d4 = elm.Dot().label('d', loc='top')
    r2 = elm.Resistor().left().label('R$_2$')
    d.pop()

    r6 = elm.Resistor().down().label('R$_6$', loc='bot')
    d5 = elm.Dot().label('g', loc='bot')

    r4 = elm.Resistor().left().label('R$_4$', loc='top').length(6)
    d5 = elm.Dot().label('f', loc='bot')
    d.pop()

    l1 = elm.Line().right().length(2)
    d.push()
    elm.Dot()
    r7 = elm.Resistor().down().label('R$_7$', loc='bot').length(6)
    elm.Dot()
    d.pop()

    l2 = elm.Line().right().length(2)
    i1 = elm.SourceI().down().length(6).reverse().label('I$_3$', loc='bot')
    
    l3 = elm.Line().left().tox(r6.end)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r1).label('i$_1$', loc='bot', color='#3b8dbf').color('#3b8dbf')
    A2 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r5).label('i$_2$', loc='top', color='#3b8dbf').color('#3b8dbf')
    A3 = elm.CurrentLabel(top=True, length=1, reverse=False).at(r3).label('i$_3$', loc='bot', color='#3b8dbf').color('#3b8dbf')
    A4 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r6).label('i$_4$', loc='top', color='#3b8dbf').color('#3b8dbf')
    A5 = elm.CurrentLabel(top=True, length=1, reverse=False).at(r4).label('i$_5$', loc='bot', color='#3b8dbf').color('#3b8dbf')
    A6 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r7).label('i$_6$', loc='top', color='#3b8dbf').color('#3b8dbf')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('40 V')
    r1 = elm.Resistor().right().label('2 Ω')
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('8 Ω').label(['+', 'V$_0$', '-'], loc='bot', color='#3b8dbf')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('6 Ω')
    d.push()
    r11 = elm.Resistor().down().label('6 Ω', loc='bot')
    elm.Dot()
    d.pop()

    d3 = elm.Dot()
    r3 = elm.Resistor().right().label('4 Ω')
    
    i2 = elm.SourceV().down().reverse().label('20 V', loc='bot')
    l2 = elm.Line().left().tox(v1.start)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('50 V')

    d.push()

    l2 = elm.Line().up().length(1.5)

    r4 = elm.Resistor().right().label('1 Ω').length(8)

    l3 = elm.Line().down().length(1.5)

    d.pop()

    r1 = elm.Resistor().right().label('5 Ω').length(4)
    d1 = elm.Dot()

    d.push()
    r2 = elm.Resistor().down().label('20 Ω', loc='bot')
    d2 = elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('4 Ω').length(4)
    
    i2 = elm.SourceControlledV().down().reverse().label('15 i$_ϕ$', loc='bot')
    l1 = elm.Line().left().tox(v1.start)

    A1 = elm.CurrentLabel(top=False, length=1, reverse=False).at(r2).label('i$_ϕ$', loc='top', color='#3b8dbf').color('#3b8dbf')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('30 V').length(4)
    r1 = elm.Resistor().right().label('3 Ω')
    d1 = elm.Dot()

    d.push()
    r6 = elm.Resistor().down().label('2 Ω').length(4)
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('8 Ω')
    d.push()
    r11 = elm.Resistor().down().label('5 Ω', loc='bot').length(4)
    elm.Dot()
    d.pop()

    d3 = elm.Dot()
    r3 = elm.Line().right()
    
    i2 = elm.SourceI().down().reverse().label('16 A', loc='bot').length(4)
    l2 = elm.Line().left()

    r4 = elm.Resistor().left().label('4 Ω', loc='top')

    r5 = elm.Resistor().left().label('6 Ω', loc='top')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('100 V')

    d.push()

    l2 = elm.Line().up().length(2.5)

    r4 = elm.Resistor().right().label('10 Ω').length(8)

    l3 = elm.Line().down().length(2.5)

    d.pop()

    r1 = elm.Resistor().right().label('3 Ω').length(4)
    d1 = elm.Dot()

    d.push()
    r2 = elm.SourceI().down().reverse().label('5 A', loc='bot').label(['+', 'v', '-'], loc='top', color='#3b8dbf')
    d2 = elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('2 Ω').length(4)
    
    i2 = elm.SourceV().down().reverse().label('50 V', loc='bot')
    
    r5 = elm.Resistor().left().label('4 Ω', loc='bot').length(4)

    r6 = elm.Resistor().left().label('6 Ω', loc='bot').length(4)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('100 V')

    d.push()

    l2 = elm.Line().up().length(2.5)

    r4 = elm.Resistor().right().label('10 Ω').length(8)

    l3 = elm.Line().down().length(2.5)

    d.pop()

    r1 = elm.Resistor().right().label('3 Ω').length(4)
    d1 = elm.Dot()

    r3 = elm.Resistor().right().label('2 Ω').length(4)
    
    i2 = elm.SourceV().down().reverse().label('50 V', loc='bot')
    
    r5 = elm.Resistor().left().label('4 Ω', loc='bot').length(4)
    d2 = elm.Dot()
    r6 = elm.Resistor().left().label('6 Ω', loc='bot').length(4)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('10 V')

    d.push()
    l2 = elm.Line().up().length(2.5)
    r4 = elm.Resistor().right().label('2 Ω').length(8)
    l3 = elm.Line().down().length(2.5)
    d.pop()

    r1 = elm.SourceI().right().label('2 A').length(4)
    d1 = elm.Dot()

    d.push()
    r2 = elm.Resistor().down().label('2 Ω', loc='bot')
    d2 = elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('2 Ω').length(4)
    
    i2 = elm.SourceV().down().label('6 V', loc='bot')
    
    r5 = elm.Resistor().left().label('1 Ω', loc='bot').length(4)

    r6 = elm.Line().tox(v1.start)
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4, fontsize=18)
    
    v1 = elm.SourceV().label('193 V', loc='bot')
    r1 = elm.Resistor().right().label('4 Ω')
    d1 = elm.Dot()

    d.push()
    r6 = elm.SourceControlledI().reverse().down().label('0,4 Δ', loc='bot').label(['+', 'V$_0$', '-'], loc='top', color='#3b8dbf')
    d2 = elm.Dot()
    d.pop()

    r2 = elm.Resistor().right().label('2,5 Ω')
    d.push()
    r11 = elm.SourceI().reverse().down().label('0,5 A', loc='bot')
    elm.Dot()
    d.pop()

    d3 = elm.Dot()
    r3 = elm.Resistor().right().label('2 Ω').label(['+', 'V$_Δ$', '-'], loc='bot', color='#3b8dbf')
    
    i2 = elm.SourceControlledV().down().reverse().label('0,8 V$_θ$', loc='bot')

    r4 = elm.Resistor().left().label('8 Ω', loc='bot')
    r5 = elm.Resistor().left().label('7,5 Ω', loc='bot').label(['-', 'V$_θ$', '+'], loc='top', color='#3b8dbf')
    r6 = elm.Resistor().left().label('6 Ω', loc='bot')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3, fontsize=18)
    
    v1 = elm.SourceV().label('256 V')

    r10 = elm.Resistor().right().label('150 Ω', loc='top')

    d3 = elm.Dot()

    d.push()
    r11 = elm.Resistor().down().label('200 Ω', loc='top')
    d4 = elm.Dot()
    d.pop()

    d.push()
    l2 = elm.Line().up().length(2.5)
    r4 = elm.Resistor().right().label('300 Ω').length(8)
    l3 = elm.Line().down().length(2.5)
    d.pop()

    r1 = elm.Resistor().right().label('100 Ω').length(4)
    d1 = elm.Dot()

    d.push()
    r2 = elm.SourceControlledV().reverse().down().label('50 iΔ', loc='top')
    d2 = elm.Dot()
    d.pop()

    r3 = elm.Resistor().right().label('250 Ω').length(4)

    d5 = elm.Dot()

    d.push()
    r13 = elm.Resistor().down().label('400 Ω', loc='top')
    d6 = elm.Dot()
    d.pop()    

    r12 = elm.Resistor().right().label('500 Ω', loc='top')
    i2 = elm.SourceV().down().label('128 V', loc='top')

    r6 = elm.Line().tox(v1.start)
    
    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=1, reverse=False).at((r4.end[0]-1, r4.end[1])).label('i$_Δ$', loc='top', color='#3b8dbf').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)
