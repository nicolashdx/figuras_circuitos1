# %%
import schemdraw
import schemdraw.elements as elm

from PIL import Image
import matplotlib.pyplot as plt

import os

# %%
def next_name(folder_path):
    # Listar todos os arquivos na pasta que terminam com .png
    png_files = [f for f in os.listdir(folder_path) if f.endswith('.png')]
    
    if not png_files:
        # Se não houver arquivos JPG, o primeiro nome será "1.png"
        return "1.png"
    
    # Remover a extensão e converter para inteiro para ordenar
    numbers = [int(os.path.splitext(f)[0]) for f in png_files]
    
    # Encontrar o maior número e adicionar 1
    next_number = max(numbers) + 1
    
    # Retornar o próximo nome de arquivo
    return f"{next_number}.png"

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceI().up().label("1 A", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right().label('+', loc='center', ofst=(0, -.3), color="gray")
    d.config(unit=3.5)

    l5 = elm.Line().down()
    d.config(unit=0.75)
    R = elm.Resistor().down().label("8 Ω", loc='top').label('V$_a$', loc='top', ofst=(0,-1.25), color='gray')
    l6 = elm.Line().down()

    l7 = elm.Line().left().label('-', loc='center', fontsize=21, ofst=(0, -.3), color='gray').label("(a)", loc='center', ofst=(0,.6), fontsize=18)
    d.config(unit=3.5)


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceV().up().label("50 V", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=3.5)

    l5 = elm.Line().down()
    d.config(unit=0.75)
    R = elm.Resistor().down().label("0,2 S", loc='top')
    l6 = elm.Line().down()

    l7 = elm.Line().left().label("(b)", loc='center', ofst=(0,.6), fontsize=18)
    d.config(unit=3.5)


    A1 = elm.CurrentLabel(top=True, ofst=.3, length=1, reverse=False).at(R).label('i$_b$', loc='bot', fontsize=18).color('gray')


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceI().up().reverse().label("1 A", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right().label('+', loc='center', ofst=(0, -.3), color="gray")
    d.config(unit=3.5)

    l5 = elm.Line().down()
    d.config(unit=0.75)
    R = elm.Resistor().down().label("20 Ω", loc='top').label('V$_c$', loc='top', ofst=(0,-1.25), color='gray')
    l6 = elm.Line().down()

    l7 = elm.Line().left().label('-', loc='center', fontsize=21, ofst=(0, -.3), color='gray').label("(c)", loc='center', ofst=(0,.6), fontsize=18)
    d.config(unit=3.5)


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.75)
    l1 = elm.Line().up()
    V1 = elm.SourceV().up().label("50 V", loc='bot')
    l2 = elm.Line().up()
    
    l3 = elm.Line().right()
    d.config(unit=3.5)

    l5 = elm.Line().down()
    d.config(unit=0.75)
    R = elm.Resistor().down().label("25 Ω", loc='top')
    l6 = elm.Line().down()

    l7 = elm.Line().left().label("(d)", loc='center', ofst=(0,.6), fontsize=18)
    d.config(unit=3.5)


    A1 = elm.CurrentLabel(top=True, ofst=.3, length=1, reverse=True).at(R).label('i$_d$', loc='bot', fontsize=18).color('gray')


    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2.5)

    d1 = elm.Dot()
    R1 = elm.Resistor().right().label("R$_1$", loc='top', fontsize=20)
    d2 = elm.Dot()
    R2 = elm.Resistor().right().label("R$_c$", loc='top', fontsize=20)
    d2 = elm.Dot()

    sw = elm.Switch()

    d3 = elm.Dot()

    l1 = elm.Line()
    d.config(unit=1)
    d4 = elm.Dot()

    R3 = elm.Resistor().up().label("R$_l$", loc='bot', fontsize=20)
    d.config(unit=3.5)
    d5 = elm.Dot()
    d.config(unit=8.5)
    l2 = elm.Line().left()

    d6 = elm.Dot()
    V1 = elm.SourceV().down().reverse().label("V$_s$", fontsize=20)
    d.config(unit=3.5)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=1)
    D1 = elm.Ic(pins=[elm.IcPin(name='2', side='b', slot='1/1', anchorname='B', color='#3b8dbf'),
                      elm.IcPin(name='1', side='t', slot='1/1', anchorname='A', color='#3b8dbf'),
                      ], pinspacing=2).label("Dispositivo", loc='center', ofst=(-.01,0)).label('V$_t$', loc='left', ofst=(-1.15, 0), color='#3b8dbf', fontsize=16).fill('lightgrey')
    

    l1 = elm.Line().left().at(D1.A).label('+', loc='left', color='#3b8dbf',fontsize=16)
    d.config(unit=2.25)
    l2 = elm.Line().left().at(D1.B).label('-', loc='left', color='#3b8dbf',fontsize=28)

    A1 = elm.CurrentLabel(top=False, ofst=-.3, length=.8, reverse=True).at(l1.center).label('I$_t$', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=2)
    d1 = elm.Dot()
    R = elm.Resistor().down().label("4 Ω", loc='bot').label('V$_t$', loc='top', ofst=(0, -2.25), color='#3b8dbf', fontsize=16)
    d2 = elm.Dot()

    rect = elm.Rect(corner1=(R.start[0]-2.25, R.start[1]+1.5), corner2=(R.end[0]+.25, R.end[1]+.5), fill='lightgrey')

    l1 = elm.Line().up().at(R.start)
    d.config(unit=.75)
    l2 = elm.Line().down().at(R.end)

    lt = elm.Line().left().at(l1.end).label('+', loc='left', color='#3b8dbf',fontsize=16)
    d.config(unit=2.5)
    lb = elm.Line().left().at(l2.end).label('-', loc='left', color='#3b8dbf',fontsize=28)

    A1 = elm.CurrentLabel(top=False, ofst=-.3, length=.8, reverse=True).at(lt.center).label('I$_t$', loc='top').color('#3b8dbf')

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3.5)
    I = elm.SourceI().up().label("2∠30° A")

    l1 = elm.Line().right()
    d.config(unit=2)

    d.push()
    r1 = elm.Resistor().down().label("5 Ω", loc='bot', fontsize=18)
    d.config(unit=3.5)
    d.pop()

    d.config(unit=2)
    r2 = elm.Resistor().right().label("3 Ω", loc='top', fontsize=18)
    ind = elm.Inductor2().label("j4 Ω", loc='top', fontsize=18)

    d.push()
    cap = elm.Capacitor().down().label("-j2 Ω", loc='bot', fontsize=18)
    d.config(unit=3.5)
    d.pop()

    d.config(unit=3.5)
    l2 = elm.Line().right()
    r3 = elm.Resistor().down().label("6 Ω", loc='bot', fontsize=18)

    l3 = elm.Line().left()
    d.config(unit=9.5)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4)
    
    V = elm.SourceV().up().label("5 V", loc='top', fontsize=18)

    r1 = elm.Resistor().right().label("5 Ω", loc='top', fontsize=18)

    d.push()
    r2 = elm.Resistor().down().label("15 Ω", loc='bot', fontsize=18)
    d.pop()

    d.push()
    r3 = elm.Resistor().right().label("6 Ω", loc='top', fontsize=18)
    r4 = elm.Resistor().down().label("20 Ω", loc='bot', fontsize=18)
    d.pop()

    l1 = elm.Line().up()
    
    d.push()
    d.config(unit=7.5)
    r5 = elm.Resistor().right().at(l1.end).label("60 Ω", loc='top', fontsize=18)
    l2 = elm.Line().down()
    d.config(unit=8)
    d.pop()

    d.config(unit=4)
    r6 = elm.Resistor().right().at(l1.center).label("12 Ω", loc='top', fontsize=18)

    d.push()
    d.config(unit=2)
    l3 = elm.Line().down()
    d.pop()

    r7 = elm.Resistor().right().endpoints(r6.end, l2.end).label("80 Ω", loc='top', fontsize=18)
    d.config(unit=11.5)
    l4 = elm.Line().left()

    A1 = elm.CurrentLabel(top=True, ofst=-.3, length=.7, reverse=False).at((V.start[0], V.start[1]+.6)).label('i$_1$', loc='bot').color('red').theta(90)
    A2 = elm.CurrentLabel(top=True, ofst=.3, length=.7, reverse=False).at((r1.start[0]+.8, r1.start[1])).label('i$_2$', loc='top').color('red').theta(0)
    A3 = elm.CurrentLabel(top=True, ofst=.3, length=.7, reverse=True).at((r2.start[0], r2.start[1]-.8)).label('i$_3$', loc='top').color('red').theta(90)
    A4 = elm.CurrentLabel(top=True, ofst=.3, length=.7, reverse=False).at((r3.start[0]+.8, r3.start[1])).label('i$_4$', loc='top').color('red').theta(0)
    A5 = elm.CurrentLabel(top=True, ofst=.3, length=.7, reverse=False).at((r6.start[0]+.8, r6.start[1])).label('i$_5$', loc='top').color('red').theta(0)
    A6 = elm.CurrentLabel(top=True, ofst=.3, length=.7, reverse=True).at((r5.end[0]-.8, r5.end[1])).label('i$_6$', loc='top').color('red').theta(0)
    A7 = elm.CurrentLabel(top=True, ofst=-.1, length=.7, reverse=False).at((r7.start[0]+1, r7.start[1]-1)).label('i$_7$', loc='top').color('red').theta(-60)
    A8 = elm.CurrentLabel(top=True, ofst=.3, length=.7, reverse=True).at((r4.start[0], r4.start[1]-.8)).label('i$_8$', loc='top').color('red').theta(90)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4)
    
    d1 = elm.Dot().label('a', loc='bot', fontsize=20)

    d.push()
    d.config(unit=2)
    l1 = elm.Line().left()
    d.pop()

    d.config(unit=4)
    r4 = elm.Resistor().right().label('4 Ω', loc='top')

    d.push()
    i1 = elm.SourceI().up().label('i$_a$', loc='top', color='red', fontsize=20)
    d2 = elm.Dot().label('b', loc='top', fontsize=20)
    d.push()
    d.config(unit=2)
    l2 = elm.Line().left()
    d.pop()
    l3 = elm.Line().right()
    d.pop()

    d.push()
    d.config(unit=4)
    l4 = elm.Line().right()
    d3 = elm.Dot().label('c', loc='bot', fontsize=20)
    l5 = elm.Line().right()
    d.config(unit=2)
    d.pop()

    d.push()
    d.config(unit=4)
    l6 = elm.Line().down()
    d4 = elm.Dot().label('d', loc='bot', fontsize=20)
    d.pop()


    r1 = elm.Resistor().endpoints(l1.end, l2.end).label('1 Ω', loc='bot')
    r2 = elm.Resistor().endpoints(r4.start, l2.start).label('2 Ω', loc='bot')
    r3 = elm.Resistor().endpoints(l3.start, l4.end).label('3 Ω', loc='top')
    r5 = elm.Resistor().endpoints(r4.start, l6.end).label('5 Ω', loc='top')

    i2 = elm.SourceI().endpoints(l5.end, l3.end).label('i$_b$', loc='top', color='red', fontsize=20)
    i3 = elm.SourceI().endpoints(l6.end, l4.end).label('i$_c$', loc='top', color='red', fontsize=20)

    A1 = elm.CurrentLabel(top=True, ofst=.25, length=1, reverse=False).at(r1).label('i$_1$', loc='top', fontsize=20).color('red')
    A2 = elm.CurrentLabel(top=True, ofst=.25, length=1, reverse=True).at(r2).label('i$_2$', loc='top', fontsize=20).color('red')
    A3 = elm.CurrentLabel(top=True, ofst=-.75, length=1, reverse=False).at(r3).label('i$_3$', loc='bot', fontsize=20).color('red')
    A4 = elm.CurrentLabel(top=True, ofst=-.75, length=1, reverse=False).at(r4).label('i$_4$', loc='bot', fontsize=20).color('red')
    A5 = elm.CurrentLabel(top=True, ofst=-.75, length=1, reverse=True).at(r5).label('i$_5$', loc='bot', fontsize=20).color('red')
    
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4)
    
    V = elm.SourceV().up().label("5 V", loc='top', fontsize=18).label(['-', 'v', '+'], loc='bot', fontsize=18, color='blue')

    r1 = elm.Resistor().right().label("5 Ω", loc='top', fontsize=18).label(['+', 'v$_1$', '-'], loc='bot', fontsize=18, color='blue')

    d.push()
    r2 = elm.Resistor().down().label("15 Ω", loc='bot', fontsize=18).label(['+', 'v$_2$', '-'], loc='top', fontsize=18, color='blue')
    d.pop()

    d.push()
    r3 = elm.Resistor().right().label("6 Ω", loc='top', fontsize=18).label(['+', 'v$_3$', '-'], loc='bot', fontsize=18, color='blue')
    r4 = elm.Resistor().down().label("20 Ω", loc='bot', fontsize=18).label(['+', 'v$_4$', '-'], loc='top', fontsize=18, color='blue')
    d.pop()

    l1 = elm.Line().up()
    
    d.push()
    d.config(unit=7.5)
    r5 = elm.Resistor().right().at(l1.end).label("60 Ω", loc='top', fontsize=18).label(['+', 'v$_6$', '-'], loc='bot', fontsize=18, color='blue')
    l2 = elm.Line().down()
    d.config(unit=8)
    d.pop()

    d.config(unit=4)
    r6 = elm.Resistor().right().at(l1.center).label("12 Ω", loc='top', fontsize=18).label(['+', 'v$_5$', '-'], loc='bot', fontsize=18, color='blue')

    d.push()
    d.config(unit=2)
    l3 = elm.Line().down()
    d.pop()

    r7 = elm.Resistor().right().endpoints(r6.end, l2.end).label("80 Ω", loc='top', fontsize=18).label(['+', 'v$_7$', '-'], loc='bot', fontsize=18, color='blue')
    d.config(unit=11.5)
    l4 = elm.Line().left()

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3)
    d1 = elm.Dot()
    v1 = elm.SourceV().up().label('V$_a$', loc='top', fontsize=16)
    d2 = elm.Dot()

    d.push()
    l1 = elm.Line().up()
    r1 = elm.Resistor().right().label('1 Ω', loc='top', fontsize=18).label(['-', 'v$_1$', '+'], loc='bot', fontsize=18, color='blue')
    d.config(unit=5)
    r2 = elm.Resistor().right().label('2 Ω', loc='top', fontsize=18).label(['+', 'v$_2$', '-'], loc='bot', fontsize=18, color='blue')
    l2 = elm.Line().down()
    d.config(unit=3)
    d.pop()

    d.config(unit=5)
    r3 = elm.Resistor().right().label('3 Ω', loc='bot', fontsize=18).label(['+', 'v$_3$', '-'], loc='top', fontsize=18, color='blue')
    d3 = elm.Dot()

    d.push()
    d.config(unit=3)
    r5 = elm.Resistor().down().label('5 Ω', loc='bot', fontsize=18, rotate=True).label(['+', 'v$_5$', '-'], loc='top', fontsize=18, color='blue')
    d4 = elm.Dot()
    d.pop()

    d.config(unit=2.5)
    v2 = elm.SourceV().right().reverse().label('V$_b$', loc='top', fontsize=16)
    r4 = elm.Resistor().right().label('4 Ω', loc='top', fontsize=18).label(['-', 'v$_4$', '+'], loc='bot', fontsize=18, color='blue')
    d5 = elm.Dot()

    d.config(unit=3)
    v3 = elm.SourceV().down().label('V$_c$', loc='bot', fontsize=16)
    d6 = elm.Dot()

    d.push()
    d.config(unit=5)
    r6 = elm.Resistor().left().label('6 Ω', loc='bot', fontsize=18).label(['-', 'v$_6$', '+'], loc='top', fontsize=18, color='blue')
    l3 = elm.Line()
    d.pop()

    d.config(unit=3)
    l4 = elm.Line().down()

    r7 = elm.Resistor().left().label('7 Ω', loc='bot', fontsize=18).label(['+', 'v$_7$', '-'], loc='top', fontsize=18, color='blue')
    d.config(unit=5)
    v4 = elm.SourceV().left().label('V$_d$', loc='bot', fontsize=16)

    l5 = elm.Line().up()
    d.config(unit=3)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.5)
    l1 = elm.Line().up()

    d1 = elm.Dot(open=True)
    v1 = elm.SourceV().up().label('180 V', loc='top', fontsize=18)
    v1.segments[2].color = 'red'
    v1.segments[3].color = 'red'
    v1.segments[4].color = 'red'
    d.config(unit=2)
    d2 = elm.Dot(open=True)
    
    l2 = elm.Line().up()
    d.config(unit=.5)
    d3 = elm.Dot()

    d.push()
    l3 = elm.Line().right()

    d4 = elm.Dot(open=True)
    r1 = elm.Resistor().right().label('5 Ω', loc='top', fontsize=18)
    d.config(unit=2)
    d5 = elm.Dot(open=True)
    
    l4 = elm.Line().right()
    d.config(unit=.5)
    d6 = elm.Dot()

    d.push()
    l5 = elm.Line().down()

    d7 = elm.Dot(open=True)
    r2 = elm.Resistor().down().label('70 Ω', loc='bot', fontsize=18)
    d.config(unit=2)
    d8 = elm.Dot(open=True)
    
    l6 = elm.Line().down()
    d.config(unit=.5)
    d9 = elm.Dot()
    d.pop()

    l7 = elm.Line().right()

    d10 = elm.Dot(open=True)
    r3 = elm.Resistor().right().label('10 Ω', loc='top', fontsize=18)
    d.config(unit=2)
    d11 = elm.Dot(open=True)
    
    l8 = elm.Line().right()
    d.config(unit=.5)
    d12 = elm.Dot()
    d.pop()

    d.config(unit=2)
    l9 = elm.Line().up()

    l10 = elm.Line().right()
    d.config(unit=2)

    d13 = elm.Dot(open=True)
    r4 = elm.Resistor().right().label('25 Ω', loc='top', fontsize=18)
    d14 = elm.Dot(open=True)

    l11 = elm.Line().right()

    l12 = elm.Line().down()
    d.config(unit=2)

    l13 = elm.Line().down()
    d.config(unit=.5)
    d1 = elm.Dot(open=True)
    r5 = elm.Resistor().down().label('8 Ω', loc='bot', fontsize=18)
    d.config(unit=2)
    d2 = elm.Dot(open=True)
    
    l14 = elm.Line().down()
    d.config(unit=.5)

    l15 = elm.Line().left().tox(v1.start)

    A0 = elm.CurrentLabel(top=True, ofst=.25, length=1, reverse=False).at(l11).label('i$_0$', loc='top', fontsize=16).color('red')
    A1 = elm.CurrentLabel(top=True, ofst=-.75, length=1, reverse=False).at(r2).label('i$_1$', loc='top', fontsize=16).color('red')
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=.5)
    l1 = elm.Line().up()

    d1 = elm.Dot(open=True)
    i1 = elm.SourceI().up().label('1 A', loc='top', fontsize=18)
    i1.segments[2].color = 'red'
    d.config(unit=2)
    d2 = elm.Dot(open=True)
    
    l2 = elm.Line().up()
    d.config(unit=.5)

    l3 = elm.Line().right()
    d.config(unit=3)
    d3 = elm.Dot()

    d.push()
    d.config(unit=.5)
    l4 = elm.Line().down()

    d4 = elm.Dot(open=True)
    r1 = elm.Resistor().down().label('12 Ω', loc='top', fontsize=18)
    d.config(unit=2)
    d5 = elm.Dot(open=True)
    
    l5 = elm.Line().down()
    d.config(unit=.5)
    d6 = elm.Dot()
    d.pop()

    d.config(unit=3)
    l6 = elm.Line().right()

    l7 = elm.Line().down()
    d.config(unit=.5)

    d7 = elm.Dot(open=True)
    v1 = elm.SourceV().down().reverse().label('5 V', loc='bot', fontsize=18)
    d.config(unit=2)
    d7 = elm.Dot(open=True)

    l8 = elm.Line().down()
    d.config(unit=.5)

    d8 = elm.Dot()

    l9 = elm.Line().left()

    d9 = elm.Dot(open=True)
    r2 = elm.Resistor().left().label('12 Ω', loc='top', fontsize=18)
    d.config(unit=2)
    d10 = elm.Dot(open=True)

    l10 = elm.Line().left().tox(i1.start)

    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=3)
    
    v1 = elm.SourceV().up().label('500 V', loc='top', fontsize=18)
    d1 = elm.Dot().label('a', loc='top', fontsize=18)

    r1 = elm.Resistor().right().label('5 Ω', loc='top', fontsize=18)
    d2 = elm.Dot().label('b', loc='top', fontsize=18)

    d.push()
    r2 = elm.Resistor().down().label('20 Ω', loc='bot', fontsize=18).label(['+', 'v$_o$', '-'], loc='top', fontsize=18, color='blue')
    d3 = elm.Dot().label('c', loc='bot', fontsize=18)
    d.pop()

    l1 = elm.Line().right()
    i1 = elm.SourceControlledI().down().reverse().label('5i$_Δ$', loc='bot', fontsize=18)

    l2 = elm.Line().left().tox(v1.start)

    A1 = elm.CurrentLabel(top=True, ofst=-.75, length=.7, reverse=False).at(r1).label('i$_Δ$', loc='bot', fontsize=16).color('red')
    A2 = elm.CurrentLabel(top=True, ofst=.3, length=.7, reverse=False).at((r2.start[0], r2.start[1]-.5)).label('i$_o$', loc='bot', fontsize=16).color('red').theta(-90)
    #d.save(next_name("./"), dpi=600, transparent=True)

# %%
with schemdraw.Drawing() as d:
    d.config(unit=4)
    
    d1 = elm.Dot()
    l1 = elm.Line().left()
    v1 = elm.SourceV().up().label('10 V', loc='bot', fontsize=18)
    l2 = elm.Line().right()
    r1 = elm.Resistor().down().label('6 Ω', loc='bot', fontsize=18)

    l3 = elm.Line().right()

    v2 = elm.SourceControlledV().up().label('3i$_s$', loc='bot', fontsize=18)
    r2 = elm.Resistor().right().label('2 Ω', loc='top', fontsize=18)
    r3 = elm.Resistor().down().label('3 Ω', loc='top', fontsize=18).label(['+', 'v$_o$', '-'], loc='bot', fontsize=18, color='blue')

    l4 = elm.Line().left()
    d2 = elm.Dot()

    A1 = elm.CurrentLabel(top=True, ofst=-.55, length=1, reverse=False).at(l2).label('i$_s$', loc='bot', fontsize=16).color('red')
    A2 = elm.CurrentLabel(top=True, ofst=-.75, length=1, reverse=False).at(r2).label('i$_o$', loc='bot', fontsize=16).color('red')
    #d.save(next_name("./"), dpi=600, transparent=True)
